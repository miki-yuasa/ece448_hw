# %% [markdown]
# # CS440/ECE448 Spring 2023
# # MP11: Reinforcement Learning

# %% [markdown]
# The first thing you need to do is to download this file: <a href="mp11.zip">mp11.zip</a>.  If you want, you can also download <a href="mp11_extra.zip">mp11_extra.zip</a>, the extra credit assignment.  `mp11.zip` has the following content:
#
# * `submitted.py`: Your homework. Edit, and then submit to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
# * `mp11_notebook.ipynb`: This is a <a href="https://anaconda.org/anaconda/jupyter">Jupyter</a> notebook to help you debug.  You can completely ignore it if you want, although you might find that it gives you useful instructions.
# * `pong.py`: This is a program that plays Pong.  If called interactively, it will call the module `pong_display.py` to create a display, so that you can play.  If told to use a Q-learner, it will call your `submitted.py` to do Q-learning.
# * `grade.py`: Once your homework seems to be working, you can test it by typing `python grade.py`, which will run the tests in `tests/tests_visible.py`.
# * `tests/test_visible.py`: This file contains about half of the <a href="https://docs.python.org/3/library/unittest.html">unit tests</a> that Gradescope will run in order to grade your homework.  If you can get a perfect score on these tests, then you should also get a perfect score on the additional hidden tests that Gradescope uses.
# * `requirements.txt`: This tells you which python packages you need to have installed, in order to run `grade.py`.  You can install all of those packages by typing `pip install -r requirements.txt` or `pip3 install -r requirements.txt`.

# %% [markdown]
# This file (`mp11_notebook.ipynb`) will walk you through the whole MP, giving you instructions and debugging tips as you go.
#
# ### Table of Contents
#
# 1. <a href="#section1">Playing Pong</a>
# 1. <a href="#section2">Creating a Q-Learner Object</a>
# 1. <a href="#section3">Epsilon-First Exploration</a>
# 1. <a href="#section4">Q-Learning</a>
# 1. <a href="#section5">Saving and Loading Your Q and N Tables</a>
# 1. <a href="#section6">Exploitation</a>
# 1. <a href="#section7">Acting</a>
# 1. <a href="#section8">Training</a>
# 1. <a href="#section9">Extra Credit</a>
# 1. <a href="#grade">Grade Your Homework</a>

# %% [markdown]
# <a id='section1'></a>

# %% [markdown]
# ## Playing Pong

# %% [markdown]
# Pong was the <a href="https://en.wikipedia.org/wiki/Pong">first video game produced by Atari.</a>  It is a simple game, based on table tennis.  Here is a two-person version of the game: https://commons.wikimedia.org/wiki/File:Pong_Game_Test2.gif
#
# We will be playing a one-person version of the game:
#
# * When the ball hits the top, bottom, or left wall of the playing field, it bounces.
# * The right end of the playing field is open, except for the paddle.  If the ball hits the paddle, it bounces, and the player's score increments by one.  If the ball hits the open space, the game is over; the score resets to zero, and a new game begins.
#
# The game is pretty simple, but in order to get a better feeling for it, you may want to try playing it yourself.  Use the up arrow to move the paddle upward, and the down arrow to move the paddle downward.  See how high you can make your score:

# %%
# !python pong.py
# Out:
# pygame 2.2.0 (SDL 2.0.22, Python 3.10.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# Once you figure out how to use the arrow keys to control your paddle, we hope you will find that the game is not too hard for a human to play.  However, for a computer, it's difficult to know: where should the paddle be moved at each time step?  In order to see how difficult it is for a computer to play, let's ask the "random" player to play the game.
#
# **WARNING:** The following line will open a pygame window.  The pygame window will be hidden by this window -- in order to see it, you will need to minimize this window.  The pygame window will consume a lot of CPU time just waiting for the processor, so in order to kill it, you will need to come back to this window, click on the block below, then click the Jupyter "stop" button (the square button at the top of this window) in order to stop processing.

# %%
# !python pong.py --player random
# Out:
# pygame 2.2.0 (SDL 2.0.22, Python 3.10.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Completed 0 games, 1 rewards, 209 frames, score 0, max score 0
# Completed 1 games, 2 rewards, 390 frames, score 0, max score 0
# Completed 2 games, 3 rewards, 571 frames, score 0, max score 0
# Completed 3 games, 4 rewards, 752 frames, score 0, max score 0
# Completed 4 games, 5 rewards, 960 frames, score 0, max score 0

# %% [markdown]
# <a id='section2'></a>

# %% [markdown]
# ## Creating a Q-Learner Object

# %% [markdown]
# The first thing you will do is to create a `q_learner` object that can store your learned Q table and your N table (table of exploration counts).
#
# Like any other object-oriented language, python permits you to create new object classes in order to store data that will be needed from time to time.  If you are not already very, very familiar with python classes, you might want to study the python class tutorial: https://docs.python.org/3/tutorial/classes.html
#
# Like any other object in python, a `q_learner` object is created by calling its name as a function, e.g., `my_q_learner=submitted.q_learner()`.  Doing so calls the function `submitted.q_learner.__init__()`.  Let's look at the docstring to see what it should do.

# %%
import submitted, importlib
importlib.reload(submitted)
help(submitted.q_learner.__init__)
# Out:
# Help on function __init__ in module submitted:
#
# __init__(self, alpha: float, epsilon: float, gamma: float, nfirst: float, state_cardinality: list[int])
#     Create a new q_learner object.
#     Your q_learner object should store the provided values of alpha,
#     epsilon, gamma, and nfirst.
#     It should also create a Q table and an N table.
#     Q[...state..., ...action...] = expected utility of state/action pair.
#     N[...state..., ...action...] = # times state/action has been explored.
#     Both are initialized to all zeros.
#     Up to you: how will you encode the state and action in order to
#     define these two lookup tables?  The state will be a list of 5 integers,
#     such that 0 <= state[i] < state_cardinality[i] for 0 <= i < 5.
#     The action will be either -1, 0, or 1.
#     It is up to you to decide how to convert an input state and action
#     into indices that you can use to access your stored Q and N tables.
#
#     @params:
#     alpha (scalar) - learning rate of the Q-learner
#     epsilon (scalar) - probability of taking a random action
#     gamma (scalar) - discount factor
#     nfirst (scalar) - exploring each state/action pair nfirst times before exploiting
#     state_cardinality (list) - cardinality of each of the quantized state variables
#
#     @return:
#     None

# %% [markdown]
# Write your `__init__` function to meet the requirements specified in the docstring.  Once you have completed it, the following code should run without errors:

# %%
importlib.reload(submitted)

q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])

print(q_learner)
# Out:
# <submitted.q_learner object at 0x000001F7EA461780>

# %% [markdown]
# <a id='section3'></a>

# %% [markdown]
# ## Epsilon-First Exploration

# %% [markdown]
# In order to manage the exploration/exploitation tradeoff, we will be using both "epsilon-first" and "epsilon-greedy" (https://en.wikipedia.org/wiki/Multi-armed_bandit#Semi-uniform_strategies).
#
# The epsilon-first strategy explores every state/action pair at least `nfirst` times before it ever starts to exploit any strategy.  Your `q_learner` should have a table to keep track of how many times it has explored a state/action pair prior to the start of any exploitation.  The method for storing that table is up to you; in order to have some standardized API, therefore, you need to write a method called `report_exploration_counts` that returns a list of the three exploration counts for a given state.

# %%
importlib.reload(submitted)
help(submitted.q_learner.report_exploration_counts)
# Out:
# Help on function report_exploration_counts in module submitted:
#
# report_exploration_counts(self, state: list[int]) -> list[int]
#     Check to see how many times each action has been explored in this state.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     explored_count (array of 3 ints):
#       number of times that each action has been explored from this state.
#       The mapping from actions to integers is up to you, but there must be three of them.

# %% [markdown]
# Write `report_exploration_counts` so that it returns a list or array for any given state.  Test your code with the following:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('This is how many times state [0,0,0,0,0] has been explored so far:')
print(q_learner.report_exploration_counts([0,0,0,0,0]))
print('This is how many times state [9,9,1,1,9] has been explored so far:')
print(q_learner.report_exploration_counts([9,9,1,1,9]))
# Out:
# This is how many times state [0,0,0,0,0] has been explored so far:
# [0, 0, 0]
# This is how many times state [9,9,1,1,9] has been explored so far:
# [0, 0, 0]

# %% [markdown]
# When your learner first starts learning, it will call the function `choose_unexplored_action` to choose an unexplored action.  This function should choose a function uniformly at random from the set of unexplored actions in a given state, if there are any:

# %%
importlib.reload(submitted)
help(submitted.q_learner.choose_unexplored_action)
# Out:
# Help on function choose_unexplored_action in module submitted:
#
# choose_unexplored_action(self, state: list[int]) -> int | None
#     Choose an action that has been explored less than nfirst times.
#     If many actions are underexplored, you should choose uniformly
#     from among those actions; don't just choose the first one all
#     the time.
#
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#        These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     action (scalar): either -1, or 0, or 1, or None
#       If all actions have been explored at least n_explore times, return None.
#       Otherwise, choose one uniformly at random from those w/count less than n_explore.
#       When you choose an action, you should increment its count in your counter table.

# %% [markdown]
# If this has been written correctly, the following block should generate a random sequence of actions.  If the next block produces the same action 5 times in a row, that is the wrong result, and the result would be that your code does not pass the autograder.

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# Next action: -1
# Next action: 1
# Next action: 1
# Next action: 0
# Next action: -1

# %% [markdown]
# After all three actions have been explored `nfirst` times, the function `choose_unexplored_action` should return `None`, as shown here:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,1,[10,10,2,2,10])
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# Next action: 0
# Next action: 1
# Next action: -1
# Next action: None

# %% [markdown]
# <a id='section4'></a>

# %% [markdown]
# ## Q-Learning

# %% [markdown]
# The reinforcement learning we are implementing is called Q-learning (https://en.wikipedia.org/wiki/Q-learning).
#
# Q-learning keeps a table $Q[s,a]$ that specifies the expected utility of action $a$ in state $s$.  The organization of this table is up to you.  In order to have a standard API, the first thing you should implement is a function `report_q` with the following docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.report_q)
# Out:
# Help on function report_q in module submitted:
#
# report_q(self, state: list[int]) -> numpy.ndarray
#     Report the current Q values for the given state.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     Q (array of 3 floats):
#       reward plus expected future utility of each of the three actions.
#       The mapping from actions to integers is up to you, but there must be three of them.

# %% [markdown]
# When your `q_learner` is first initialized, the value of $Q[state,action]$ should be zero for all state/action pairs, thus the `report_q` function should return lists of zeros:

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Q[0,0,0,0,0] is now:',q_learner.report_q([0,0,0,0,0]))
print('Q[9,9,1,1,9] is now:',q_learner.report_q([9,9,1,1,9]))
# Out:
# Q[0,0,0,0,0] is now: [0. 0. 0.]
# Q[9,9,1,1,9] is now: [0. 0. 0.]

# %% [markdown]
# There are actually many different Q-learning algorithms available, but when people refer to Q-learning with no modifier, they usually mean the time-difference (TD) algorithm.  For example, this is the algorithm that's described on the wikipedia page (https://en.wikipedia.org/wiki/Q-learning).  This is the algorithm you will implement for this MP.
#
# In supervised machine learning, the learner tries to imitate a reference label.  In reinforcement learning, there is no reference label.  Q-learning replaces the reference label with a "local Q" value, which is the utility that was obtained by performing action $a$ in state $s$ one time.  It is usually calculated like this:
#
# $$Q_{local}(s_t,a_t) = r_t + \gamma\max_{a_{t+1}}Q(s_{t+1},a_{t+1})$$
#
# where $r_t$ is the reward that was achieved by performing action $a_t$ in state $s_t$, $s_{t+1}$ is the state into which the game transitioned, and $a_{t+1}$ is one of the actions that could be performed in that state.  $Q_{local}$ is computed by your `q_local` function, which has this docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.q_local)
# Out:
# Help on function q_local in module submitted:
#
# q_local(self, reward: float, newstate: list[int])
#     The update to Q estimated from a single step of game play:
#     reward plus gamma times the max of Q[newstate, ...].
#
#     @param:
#     reward (scalar float): the reward achieved from the current step of game play.
#     newstate (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     Q_local (scalar float): the local value of Q

# %% [markdown]
# Initially, `q_local` should just return the given reward, because initially, all Q values are 0:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,10,10])
print('Q_local(6.25,[9,9,1,1,9]) is currently:',q_learner.q_local(6.25,[9,9,1,1,9]))
# Out:
# Q_local(6.25,[9,9,1,1,9]) is currently: 6.25

# %% [markdown]
# Now you can use `q_learner.q_local` as the target for `q_learner.learn`.  The basic algorithm is
#
# $$Q(s,a) = Q(s,a) + \alpha (Q_{local}(s,a)-Q(s,a))$$
#
# Here is the docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.learn)
# Out:
# Help on function learn in module submitted:
#
# learn(self, state: list[int], action: int, reward: float, newstate: list[int])
#     Update the internal Q-table on the basis of an observed
#     state, action, reward, newstate sequence.
#
#     @params:
#     state: a list of 5 numbers: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle.
#     action: an integer, one of -1, 0, or +1
#     reward: a reward; positive for hitting the ball, negative for losing a game
#     newstate: a list of 5 numbers, in the same format as state
#
#     @return:
#     None

# %% [markdown]
# The following block checks a sequence of Q updates:
#
# 1. First, $Q([9,9,1,1,9],-1)$ is updated.  Since all Q values start at zero, it will be updated to just have a value equal to $\alpha$ (0.05) times the given reward (6.25) for a total value of 0.3125.
# 1. When we print out $Q([9,9,1,1,9],:)$, we see that one of the elements has been updated.
# 1. Next, update $Q([9,9,1,1,8],1)$ with a given reward, and with $[9,9,1,1,9]$ as the given next state.  Since $Q([9,9,1,1,9],-1)$ is larger than zero, the next-state Q-value should be multiplied by $\gamma$ (0.99) and added to the reward (3.1), then multiplied by $\alpha$, giving a total value of 0.17046875.
# 1. The resulting Q-value is reported.

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q[9,9,1,1,9] is now',q_learner.report_q([9,9,1,1,9]))
q_learner.learn([9,9,1,1,8],1,3.1,[9,9,1,1,9])
print('Q[9,9,1,1,8] is now',q_learner.report_q([9,9,1,1,8]))
# Out:
# Q[9,9,1,1,9] is now [0.     0.     0.3125]
# Q[9,9,1,1,8] is now [0.         0.17046875 0.        ]

# %% [markdown]
# <a id='section5'></a>

# %% [markdown]
# ## Saving and Loading your Q and N Tables

# %% [markdown]
# After you've spent a long time training your `q_learner`, you will want to save your Q and N tables so that you can reload them later.  The format of Q and N is up to you, therefore it's also up to you to write the `save` and `load` functions.  Here are the docstrings:

# %%
importlib.reload(submitted)
help(submitted.q_learner.save)
# Out:
# Help on function save in module submitted:
#
# save(self, filename: str)
#     Save your Q and N tables to a file.
#     This can save in any format you like, as long as your "load"
#     function uses the same file format.  We recommend numpy.savez,
#     but you can use something else if you prefer.
#
#     @params:
#     filename (str) - filename to which it should be saved
#     @return:
#     None

# %%
importlib.reload(submitted)
help(submitted.q_learner.load)
# Out:
# Help on function load in module submitted:
#
# load(self, filename: str)
#     Load the Q and N tables from a file.
#     This should load from whatever file format your save function
#     used.  We recommend numpy.load, but you can use something
#     else if you prefer.
#
#     @params:
#     filename (str) - filename from which it should be loaded
#     @return:
#     None

# %% [markdown]
# These functions can be tested by doing one step of training one `q_learner`, then saving its results, then loading them into another `q_learner`:

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Next action:',q_learner1.choose_unexplored_action([9,9,1,1,9]))
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('N1[9,9,1,1,8] is now',q_learner1.report_exploration_counts([9,9,1,1,9]))
print('Q1[9,9,1,1,8] is now',q_learner1.report_q([9,9,1,1,9]))
q_learner1.save('test.npz')

q_learner2 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('N2[9,9,1,1,8] starts out as',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] starts out as',q_learner2.report_q([9,9,1,1,9]))
q_learner2.load('test.npz')
print('N2[9,9,1,1,8] is now',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] is now',q_learner2.report_q([9,9,1,1,9]))
# Out:
# Next action: 0
# N1[9,9,1,1,8] is now [1, 0, 0]
# Q1[9,9,1,1,8] is now [0.     0.     0.3125]
# N2[9,9,1,1,8] starts out as [0, 0, 0]
# Q2[9,9,1,1,8] starts out as [0. 0. 0.]
# N2[9,9,1,1,8] is now [1, 0, 0]
# Q2[9,9,1,1,8] is now [0.     0.     0.3125]

# %% [markdown]
# <a id='section6'></a>

# %% [markdown]
# ## Exploitation

# %% [markdown]
# A reinforcement learner always has to trade off between exploration (choosing an action at random) versus exploitation (choosing the action with the maximum expected utility).  Before we worry about that tradeoff, though, let's first make sure that exploitation works.

# %%
importlib.reload(submitted)
help(submitted.q_learner.exploit)
# Out:
# Help on function exploit in module submitted:
#
# exploit(self, state: list[int]) -> tuple[int, float]
#     Return the action that has the highest Q-value for the current state, and its Q-value.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     action (scalar int): either -1, or 0, or 1.
#       The action that has the highest Q-value.  Ties can be broken any way you want.
#     Q (scalar float):
#       The Q-value of the selected action

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q1[9,9,1,1,9] is now',q_learner1.report_q([9,9,1,1,9]))
print('The best action and Q from state [9,9,1,1,9] are',q_learner1.exploit([9,9,1,1,9]))
# Out:
# Q1[9,9,1,1,9] is now [0.     0.     0.3125]
# The best action and Q from state [9,9,1,1,9] are (-1, 0.3125)

# %% [markdown]
# <a id='section7'></a>

# %% [markdown]
# ## Acting

# %% [markdown]
# When your learner decides which action to perform, it should trade off exploration vs. exploitation using both the epsilon-first and the epsilon-greedy strategies:
# 1. If there is any action that has been explored fewer than `nfirst` times, then choose one of those actions at random.  Otherwise...
# 1. With probability `epsilon`, choose an action at random.  Otherwise...
# 1. Exploit.

# %%
importlib.reload(submitted)
help(submitted.q_learner.act)
# Out:
# Help on function act in module submitted:
#
# act(self, state: list[int]) -> int
#     Decide what action to take in the current state.
#     If any action has been taken less than nfirst times, then choose one of those
#     actions, uniformly at random.
#     Otherwise, with probability epsilon, choose an action uniformly at random.
#     Otherwise, choose the action with the best Q(state,action).
#
#     @params:
#     state: a list of 5 integers: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     -1 if the paddle should move upward
#     0 if the paddle should be stationary
#     1 if the paddle should move downward

# %% [markdown]
# In order to test all three types of action (epsilon-first exploration, epsilon-greedy exploration, and exploitation), let's create a learner with `nfirst=1` and `epsilon=0.25`, and set it so that the best action from state `[9,9,1,1,9]` is `-1`.  With these settings, a sequence of calls to `q_learner.act` should produce the following sequence of actions:
#
# 1. The first three actions should include each possible action once.
# 1. After the first three actions, 3/4 of the remaining actions should be `-1`.  The remaining 1/4 should be randomly chosen.

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.25,0.99,1,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
# Out:
# An epsilon-first action: 0
# An epsilon-first action: 1
# An epsilon-first action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: 0
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1

# %% [markdown]
# <a id='section8'></a>

# %% [markdown]
# ## Training

# %% [markdown]
# Now that all of your components work, you can try training your algorithm.  Do this by giving your `q_learner` as a player to a new `pong.PongGame` object.  Set `visibility=False` so that the `PongGame` doesn't create a new window.

# %%
import pong, importlib, submitted
importlib.reload(pong)
help(pong.PongGame.__init__)
# Out:
# Help on function __init__ in module pong:
#
# __init__(self, ball_speed=4, paddle_speed=8, learner=None, visible=True, state_quantization=[10, 10, 2, 2, 10])
#     Create a new pong game, with a specified player.
#
#     @params:
#     ball_speed (scalar int) - average ball speed in pixels/frame
#     paddle_speed (scalar int) - paddle moves 0, +paddle_speed, or -paddle_speed
#     learner - can be None if the player is human.  If not None, should be an
#       object of type random_learner, submitted.q_learner, or submitted.deep_q.
#     visible (bool) - should this game have an attached pygame window?
#     state_quantization (list) - if not None, state variables are quantized
#       into integers of these cardinalities before being passed to the learner.

# %% [markdown]
# As you can see, we should set `visibility=False` so that the `PongGame` doesn't create a new window.  We should also make sure that the PongGame uses the same state quantization as the learner.

# %%
importlib.reload(pong)
importlib.reload(submitted)
state_quantization = [10,10,2,2,10]
q_learner=submitted.q_learner(0.05,0.05,0.99,5,state_quantization)

pong_game = pong.PongGame(learner=q_learner, visible=False, state_quantization=state_quantization)
print(pong_game)
# Out:
# <pong.PongGame object at 0x000001F805107730>

# %% [markdown]
# In order to train our learner, we want it to play the game many times.  To do that we use the PongGame.run function:

# %%
help(pong_game.run)
# Out:
# Help on method run in module pong:
#
# run(m_rewards=inf, m_games=inf, m_frames=inf, states=[]) method of pong.PongGame instance
#     Run the game.
#     @param
#     m_frames (scalar int): maximum number of frames to be played
#     m_rewards (scalar int): maximum number of rewards earned (+ or -)
#     m_games (scalar int): maximum number of games
#     states (list): list of states whose Q-values should be returned
#        each state is a list of 5 ints: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#        These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#        and the y-position of the paddle, all quantized.
#        0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#
#     @return
#     scores (list): list of scores of all completed games
#
#     The following will be returned only if the player is q_learning or deep_q.
#     New elements will be added to these lists once/frame if m_frames is specified,
#     else once/reward if m_rewards is specified, else once/game:
#       q_achieved (list): list of the q-values of the moves that were taken
#       q_states (list): list of the q-values of requested states

# %% [markdown]
# In order to make sure our learner is learning, let's tell `pong_game.run` to output all 3 Q-values of all of the 4000 states in every time step.
#
# To make sure that's not an outrageous amount of data, let's tell it to only output the Q values once/reward, and ask it to only collect 5000 rewards:

# %%
states = [[x,y,vx,vy,py] for x in range(10) for y in range(10) for vx in range(2) for vy in range(2) for py in range(10) ]

scores, q_achieved, q_states = pong_game.run(m_rewards=500, states=states)

print('The number of games played was',len(scores))
print('The number of rewards was',len(q_states))
print('The size of each returned Q-matrix was',q_states[0].shape)
# Out:
# Completed 0 games, 2 rewards, 484 frames, score 1, max score 1
# Completed 1 games, 3 rewards, 692 frames, score 0, max score 1
# Completed 2 games, 4 rewards, 900 frames, score 0, max score 1
# Completed 3 games, 5 rewards, 1081 frames, score 0, max score 1
# Completed 4 games, 9 rewards, 1858 frames, score 3, max score 3
# Completed 5 games, 13 rewards, 2825 frames, score 3, max score 3
# Completed 6 games, 14 rewards, 3006 frames, score 0, max score 3
# Completed 7 games, 15 rewards, 3214 frames, score 0, max score 3
# Completed 8 games, 16 rewards, 3468 frames, score 0, max score 3
# Completed 9 games, 17 rewards, 3676 frames, score 0, max score 3
# Completed 10 games, 18 rewards, 3930 frames, score 0, max score 3
# Completed 11 games, 21 rewards, 4422 frames, score 2, max score 3
# Completed 12 games, 22 rewards, 4630 frames, score 0, max score 3
# Completed 13 games, 25 rewards, 5495 frames, score 2, max score 3
# Completed 14 games, 27 rewards, 5847 frames, score 1, max score 3
# Completed 15 games, 28 rewards, 6028 frames, score 0, max score 3
# Completed 16 games, 30 rewards, 6456 frames, score 1, max score 3
# Completed 17 games, 32 rewards, 6919 frames, score 1, max score 3
# Completed 18 games, 36 rewards, 9997 frames, score 3, max score 3
# Completed 19 games, 37 rewards, 10251 frames, score 0, max score 3
# Completed 20 games, 38 rewards, 10459 frames, score 0, max score 3
# Completed 21 games, 39 rewards, 10667 frames, score 0, max score 3
# Completed 22 games, 40 rewards, 10848 frames, score 0, max score 3
# Completed 23 games, 42 rewards, 11246 frames, score 1, max score 3
# Completed 24 games, 45 rewards, 11906 frames, score 2, max score 3
# Completed 25 games, 46 rewards, 12160 frames, score 0, max score 3
# Completed 26 games, 47 rewards, 12341 frames, score 0, max score 3
# Completed 27 games, 49 rewards, 12838 frames, score 1, max score 3
# Completed 28 games, 50 rewards, 13092 frames, score 0, max score 3
# Completed 29 games, 53 rewards, 14241 frames, score 2, max score 3
# Completed 30 games, 54 rewards, 14422 frames, score 0, max score 3
# Completed 31 games, 55 rewards, 14630 frames, score 0, max score 3
# Completed 32 games, 57 rewards, 15067 frames, score 1, max score 3
# Completed 33 games, 60 rewards, 15783 frames, score 2, max score 3
# Completed 34 games, 61 rewards, 16037 frames, score 0, max score 3
# Completed 35 games, 62 rewards, 16291 frames, score 0, max score 3
# Completed 36 games, 63 rewards, 16545 frames, score 0, max score 3
# Completed 37 games, 64 rewards, 16753 frames, score 0, max score 3
# Completed 38 games, 65 rewards, 16934 frames, score 0, max score 3
# Completed 39 games, 66 rewards, 17142 frames, score 0, max score 3
# Completed 40 games, 68 rewards, 17570 frames, score 1, max score 3
# Completed 41 games, 69 rewards, 17778 frames, score 0, max score 3
# Completed 42 games, 71 rewards, 18161 frames, score 1, max score 3
# Completed 43 games, 72 rewards, 18342 frames, score 0, max score 3
# Completed 44 games, 73 rewards, 18550 frames, score 0, max score 3
# Completed 45 games, 75 rewards, 19021 frames, score 1, max score 3
# Completed 46 games, 76 rewards, 19229 frames, score 0, max score 3
# Completed 47 games, 77 rewards, 19437 frames, score 0, max score 3
# Completed 48 games, 78 rewards, 19691 frames, score 0, max score 3
# Completed 49 games, 81 rewards, 20372 frames, score 2, max score 3
# Completed 50 games, 82 rewards, 20580 frames, score 0, max score 3
# Completed 51 games, 83 rewards, 20834 frames, score 0, max score 3
# Completed 52 games, 86 rewards, 22692 frames, score 2, max score 3
# Completed 53 games, 87 rewards, 22900 frames, score 0, max score 3
# Completed 54 games, 88 rewards, 23081 frames, score 0, max score 3
# Completed 55 games, 90 rewards, 23448 frames, score 1, max score 3
# Completed 56 games, 91 rewards, 23629 frames, score 0, max score 3
# Completed 57 games, 92 rewards, 23837 frames, score 0, max score 3
# Completed 58 games, 93 rewards, 24018 frames, score 0, max score 3
# Completed 59 games, 95 rewards, 24385 frames, score 1, max score 3
# Completed 60 games, 96 rewards, 24593 frames, score 0, max score 3
# Completed 61 games, 97 rewards, 24774 frames, score 0, max score 3
# Completed 62 games, 98 rewards, 24982 frames, score 0, max score 3
# Completed 63 games, 99 rewards, 25163 frames, score 0, max score 3
# Completed 64 games, 100 rewards, 25371 frames, score 0, max score 3
# Completed 65 games, 101 rewards, 25579 frames, score 0, max score 3
# Completed 66 games, 102 rewards, 25760 frames, score 0, max score 3
# Completed 67 games, 103 rewards, 26014 frames, score 0, max score 3
# Completed 68 games, 104 rewards, 26268 frames, score 0, max score 3
# Completed 69 games, 107 rewards, 26907 frames, score 2, max score 3
# Completed 70 games, 110 rewards, 27598 frames, score 2, max score 3
# Completed 71 games, 111 rewards, 27852 frames, score 0, max score 3
# Completed 72 games, 114 rewards, 28629 frames, score 2, max score 3
# Completed 73 games, 115 rewards, 28837 frames, score 0, max score 3
# Completed 74 games, 117 rewards, 29220 frames, score 1, max score 3
# Completed 75 games, 118 rewards, 29401 frames, score 0, max score 3
# Completed 76 games, 123 rewards, 30291 frames, score 4, max score 4
# Completed 77 games, 125 rewards, 30788 frames, score 1, max score 4
# Completed 78 games, 127 rewards, 31225 frames, score 1, max score 4
# Completed 79 games, 129 rewards, 31662 frames, score 1, max score 4
# Completed 80 games, 130 rewards, 31843 frames, score 0, max score 4
# Completed 81 games, 131 rewards, 32024 frames, score 0, max score 4
# Completed 82 games, 132 rewards, 32205 frames, score 0, max score 4
# Completed 83 games, 133 rewards, 32459 frames, score 0, max score 4
# Completed 84 games, 134 rewards, 32713 frames, score 0, max score 4
# Completed 85 games, 135 rewards, 32921 frames, score 0, max score 4
# Completed 86 games, 136 rewards, 33102 frames, score 0, max score 4
# Completed 87 games, 137 rewards, 33310 frames, score 0, max score 4
# Completed 88 games, 139 rewards, 33750 frames, score 1, max score 4
# Completed 89 games, 140 rewards, 33931 frames, score 0, max score 4
# Completed 90 games, 141 rewards, 34139 frames, score 0, max score 4
# Completed 91 games, 142 rewards, 34320 frames, score 0, max score 4
# Completed 92 games, 143 rewards, 34574 frames, score 0, max score 4
# Completed 93 games, 145 rewards, 35236 frames, score 1, max score 4
# Completed 94 games, 147 rewards, 35733 frames, score 1, max score 4
# Completed 95 games, 148 rewards, 35987 frames, score 0, max score 4
# Completed 96 games, 149 rewards, 36195 frames, score 0, max score 4
# Completed 97 games, 150 rewards, 36403 frames, score 0, max score 4
# Completed 98 games, 152 rewards, 36813 frames, score 1, max score 4
# Completed 99 games, 154 rewards, 37389 frames, score 1, max score 4
# Completed 100 games, 156 rewards, 37965 frames, score 1, max score 4
# Completed 101 games, 157 rewards, 38219 frames, score 0, max score 4
# Completed 102 games, 159 rewards, 38953 frames, score 1, max score 4
# Completed 103 games, 160 rewards, 39207 frames, score 0, max score 4
# Completed 104 games, 161 rewards, 39415 frames, score 0, max score 4
# Completed 105 games, 162 rewards, 39623 frames, score 0, max score 4
# Completed 106 games, 163 rewards, 39804 frames, score 0, max score 4
# Completed 107 games, 164 rewards, 40058 frames, score 0, max score 4
# Completed 108 games, 166 rewards, 40660 frames, score 1, max score 4
# Completed 109 games, 168 rewards, 41195 frames, score 1, max score 4
# Completed 110 games, 169 rewards, 41376 frames, score 0, max score 4
# Completed 111 games, 170 rewards, 41630 frames, score 0, max score 4
# Completed 112 games, 172 rewards, 42067 frames, score 1, max score 4
# Completed 113 games, 173 rewards, 42248 frames, score 0, max score 4
# Completed 114 games, 174 rewards, 42429 frames, score 0, max score 4
# Completed 115 games, 175 rewards, 42683 frames, score 0, max score 4
# Completed 116 games, 176 rewards, 42891 frames, score 0, max score 4
# Completed 117 games, 178 rewards, 43258 frames, score 1, max score 4
# Completed 118 games, 179 rewards, 43512 frames, score 0, max score 4
# Completed 119 games, 180 rewards, 43693 frames, score 0, max score 4
# Completed 120 games, 181 rewards, 43901 frames, score 0, max score 4
# Completed 121 games, 182 rewards, 44082 frames, score 0, max score 4
# Completed 122 games, 183 rewards, 44290 frames, score 0, max score 4
# Completed 123 games, 184 rewards, 44498 frames, score 0, max score 4
# Completed 124 games, 186 rewards, 44850 frames, score 1, max score 4
# Completed 125 games, 187 rewards, 45031 frames, score 0, max score 4
# Completed 126 games, 188 rewards, 45212 frames, score 0, max score 4
# Completed 127 games, 190 rewards, 45746 frames, score 1, max score 4
# Completed 128 games, 192 rewards, 46297 frames, score 1, max score 4
# Completed 129 games, 193 rewards, 46551 frames, score 0, max score 4
# Completed 130 games, 194 rewards, 46732 frames, score 0, max score 4
# Completed 131 games, 195 rewards, 46913 frames, score 0, max score 4
# Completed 132 games, 196 rewards, 47121 frames, score 0, max score 4
# Completed 133 games, 197 rewards, 47329 frames, score 0, max score 4
# Completed 134 games, 198 rewards, 47510 frames, score 0, max score 4
# Completed 135 games, 199 rewards, 47764 frames, score 0, max score 4
# Completed 136 games, 201 rewards, 48364 frames, score 1, max score 4
# Completed 137 games, 202 rewards, 48618 frames, score 0, max score 4
# Completed 138 games, 203 rewards, 48799 frames, score 0, max score 4
# Completed 139 games, 204 rewards, 49053 frames, score 0, max score 4
# Completed 140 games, 205 rewards, 49307 frames, score 0, max score 4
# Completed 141 games, 207 rewards, 49770 frames, score 1, max score 4
# Completed 142 games, 209 rewards, 50153 frames, score 1, max score 4
# Completed 143 games, 210 rewards, 50361 frames, score 0, max score 4
# Completed 144 games, 212 rewards, 50713 frames, score 1, max score 4
# Completed 145 games, 213 rewards, 50967 frames, score 0, max score 4
# Completed 146 games, 214 rewards, 51175 frames, score 0, max score 4
# Completed 147 games, 215 rewards, 51383 frames, score 0, max score 4
# Completed 148 games, 216 rewards, 51637 frames, score 0, max score 4
# Completed 149 games, 217 rewards, 51818 frames, score 0, max score 4
# Completed 150 games, 218 rewards, 52026 frames, score 0, max score 4
# Completed 151 games, 219 rewards, 52234 frames, score 0, max score 4
# Completed 152 games, 220 rewards, 52488 frames, score 0, max score 4
# Completed 153 games, 221 rewards, 52696 frames, score 0, max score 4
# Completed 154 games, 224 rewards, 53342 frames, score 2, max score 4
# Completed 155 games, 225 rewards, 53523 frames, score 0, max score 4
# Completed 156 games, 226 rewards, 53731 frames, score 0, max score 4
# Completed 157 games, 227 rewards, 53912 frames, score 0, max score 4
# Completed 158 games, 228 rewards, 54120 frames, score 0, max score 4
# Completed 159 games, 230 rewards, 54617 frames, score 1, max score 4
# Completed 160 games, 231 rewards, 54825 frames, score 0, max score 4
# Completed 161 games, 232 rewards, 55033 frames, score 0, max score 4
# Completed 162 games, 233 rewards, 55241 frames, score 0, max score 4
# Completed 163 games, 234 rewards, 55422 frames, score 0, max score 4
# Completed 164 games, 235 rewards, 55630 frames, score 0, max score 4
# Completed 165 games, 239 rewards, 56497 frames, score 3, max score 4
# Completed 166 games, 241 rewards, 56968 frames, score 1, max score 4
# Completed 167 games, 242 rewards, 57222 frames, score 0, max score 4
# Completed 168 games, 243 rewards, 57476 frames, score 0, max score 4
# Completed 169 games, 244 rewards, 57684 frames, score 0, max score 4
# Completed 170 games, 245 rewards, 57892 frames, score 0, max score 4
# Completed 171 games, 246 rewards, 58100 frames, score 0, max score 4
# Completed 172 games, 247 rewards, 58308 frames, score 0, max score 4
# Completed 173 games, 248 rewards, 58489 frames, score 0, max score 4
# Completed 174 games, 249 rewards, 58697 frames, score 0, max score 4
# Completed 175 games, 251 rewards, 59359 frames, score 1, max score 4
# Completed 176 games, 252 rewards, 59613 frames, score 0, max score 4
# Completed 177 games, 253 rewards, 59867 frames, score 0, max score 4
# Completed 178 games, 254 rewards, 60075 frames, score 0, max score 4
# Completed 179 games, 255 rewards, 60329 frames, score 0, max score 4
# Completed 180 games, 256 rewards, 60537 frames, score 0, max score 4
# Completed 181 games, 257 rewards, 60718 frames, score 0, max score 4
# Completed 182 games, 258 rewards, 60926 frames, score 0, max score 4
# Completed 183 games, 263 rewards, 63008 frames, score 4, max score 4
# Completed 184 games, 269 rewards, 64803 frames, score 5, max score 5
# Completed 185 games, 271 rewards, 65144 frames, score 1, max score 5
# Completed 186 games, 272 rewards, 65352 frames, score 0, max score 5
# Completed 187 games, 273 rewards, 65533 frames, score 0, max score 5
# Completed 188 games, 274 rewards, 65741 frames, score 0, max score 5
# Completed 189 games, 276 rewards, 66292 frames, score 1, max score 5
# Completed 190 games, 277 rewards, 66500 frames, score 0, max score 5
# Completed 191 games, 278 rewards, 66708 frames, score 0, max score 5
# Completed 192 games, 279 rewards, 66962 frames, score 0, max score 5
# Completed 193 games, 280 rewards, 67170 frames, score 0, max score 5
# Completed 194 games, 281 rewards, 67424 frames, score 0, max score 5
# Completed 195 games, 283 rewards, 68086 frames, score 1, max score 5
# Completed 196 games, 285 rewards, 68469 frames, score 1, max score 5
# Completed 197 games, 286 rewards, 68677 frames, score 0, max score 5
# Completed 198 games, 287 rewards, 68885 frames, score 0, max score 5
# Completed 199 games, 288 rewards, 69093 frames, score 0, max score 5
# Completed 200 games, 289 rewards, 69274 frames, score 0, max score 5
# Completed 201 games, 290 rewards, 69528 frames, score 0, max score 5
# Completed 202 games, 291 rewards, 69736 frames, score 0, max score 5
# Completed 203 games, 293 rewards, 70173 frames, score 1, max score 5
# Completed 204 games, 294 rewards, 70427 frames, score 0, max score 5
# Completed 205 games, 295 rewards, 70681 frames, score 0, max score 5
# Completed 206 games, 296 rewards, 70889 frames, score 0, max score 5
# Completed 207 games, 297 rewards, 71143 frames, score 0, max score 5
# Completed 208 games, 298 rewards, 71397 frames, score 0, max score 5
# Completed 209 games, 299 rewards, 71651 frames, score 0, max score 5
# Completed 210 games, 300 rewards, 71832 frames, score 0, max score 5
# Completed 211 games, 301 rewards, 72086 frames, score 0, max score 5
# Completed 212 games, 302 rewards, 72267 frames, score 0, max score 5
# Completed 213 games, 303 rewards, 72448 frames, score 0, max score 5
# Completed 214 games, 304 rewards, 72656 frames, score 0, max score 5
# Completed 215 games, 305 rewards, 72864 frames, score 0, max score 5
# Completed 216 games, 306 rewards, 73118 frames, score 0, max score 5
# Completed 217 games, 308 rewards, 73615 frames, score 1, max score 5
# Completed 218 games, 309 rewards, 73869 frames, score 0, max score 5
# Completed 219 games, 310 rewards, 74077 frames, score 0, max score 5
# Completed 220 games, 311 rewards, 74258 frames, score 0, max score 5
# Completed 221 games, 313 rewards, 74737 frames, score 1, max score 5
# Completed 222 games, 314 rewards, 74991 frames, score 0, max score 5
# Completed 223 games, 315 rewards, 75199 frames, score 0, max score 5
# Completed 224 games, 317 rewards, 75861 frames, score 1, max score 5
# Completed 225 games, 320 rewards, 76398 frames, score 2, max score 5
# Completed 226 games, 321 rewards, 76606 frames, score 0, max score 5
# Completed 227 games, 323 rewards, 76947 frames, score 1, max score 5
# Completed 228 games, 325 rewards, 77498 frames, score 1, max score 5
# Completed 229 games, 328 rewards, 78300 frames, score 2, max score 5
# Completed 230 games, 329 rewards, 78481 frames, score 0, max score 5
# Completed 231 games, 330 rewards, 78689 frames, score 0, max score 5
# Completed 232 games, 331 rewards, 78897 frames, score 0, max score 5
# Completed 233 games, 332 rewards, 79105 frames, score 0, max score 5
# Completed 234 games, 333 rewards, 79359 frames, score 0, max score 5
# Completed 235 games, 334 rewards, 79567 frames, score 0, max score 5
# Completed 236 games, 335 rewards, 79821 frames, score 0, max score 5
# Completed 237 games, 337 rewards, 80318 frames, score 1, max score 5
# Completed 238 games, 338 rewards, 80499 frames, score 0, max score 5
# Completed 239 games, 339 rewards, 80707 frames, score 0, max score 5
# Completed 240 games, 341 rewards, 81178 frames, score 1, max score 5
# Completed 241 games, 342 rewards, 81359 frames, score 0, max score 5
# Completed 242 games, 343 rewards, 81567 frames, score 0, max score 5
# Completed 243 games, 344 rewards, 81821 frames, score 0, max score 5
# Completed 244 games, 346 rewards, 82227 frames, score 1, max score 5
# Completed 245 games, 347 rewards, 82408 frames, score 0, max score 5
# Completed 246 games, 348 rewards, 82662 frames, score 0, max score 5
# Completed 247 games, 349 rewards, 82916 frames, score 0, max score 5
# Completed 248 games, 350 rewards, 83124 frames, score 0, max score 5
# Completed 249 games, 352 rewards, 84044 frames, score 1, max score 5
# Completed 250 games, 353 rewards, 84225 frames, score 0, max score 5
# Completed 251 games, 354 rewards, 84433 frames, score 0, max score 5
# Completed 252 games, 355 rewards, 84641 frames, score 0, max score 5
# Completed 253 games, 358 rewards, 85583 frames, score 2, max score 5
# Completed 254 games, 359 rewards, 85791 frames, score 0, max score 5
# Completed 255 games, 360 rewards, 85999 frames, score 0, max score 5
# Completed 256 games, 361 rewards, 86207 frames, score 0, max score 5
# Completed 257 games, 363 rewards, 86741 frames, score 1, max score 5
# Completed 258 games, 364 rewards, 86922 frames, score 0, max score 5
# Completed 259 games, 365 rewards, 87176 frames, score 0, max score 5
# Completed 260 games, 369 rewards, 87988 frames, score 3, max score 5
# Completed 261 games, 370 rewards, 88242 frames, score 0, max score 5
# Completed 262 games, 371 rewards, 88496 frames, score 0, max score 5
# Completed 263 games, 372 rewards, 88677 frames, score 0, max score 5
# Completed 264 games, 374 rewards, 89060 frames, score 1, max score 5
# Completed 265 games, 375 rewards, 89241 frames, score 0, max score 5
# Completed 266 games, 376 rewards, 89422 frames, score 0, max score 5
# Completed 267 games, 377 rewards, 89630 frames, score 0, max score 5
# Completed 268 games, 378 rewards, 89838 frames, score 0, max score 5
# Completed 269 games, 380 rewards, 90244 frames, score 1, max score 5
# Completed 270 games, 381 rewards, 90425 frames, score 0, max score 5
# Completed 271 games, 382 rewards, 90606 frames, score 0, max score 5
# Completed 272 games, 385 rewards, 91292 frames, score 2, max score 5
# Completed 273 games, 386 rewards, 91546 frames, score 0, max score 5
# Completed 274 games, 389 rewards, 92153 frames, score 2, max score 5
# Completed 275 games, 390 rewards, 92334 frames, score 0, max score 5
# Completed 276 games, 391 rewards, 92588 frames, score 0, max score 5
# Completed 277 games, 392 rewards, 92769 frames, score 0, max score 5
# Completed 278 games, 393 rewards, 92977 frames, score 0, max score 5
# Completed 279 games, 397 rewards, 93881 frames, score 3, max score 5
# Completed 280 games, 398 rewards, 94062 frames, score 0, max score 5
# Completed 281 games, 399 rewards, 94270 frames, score 0, max score 5
# Completed 282 games, 403 rewards, 94995 frames, score 3, max score 5
# Completed 283 games, 404 rewards, 95203 frames, score 0, max score 5
# Completed 284 games, 405 rewards, 95457 frames, score 0, max score 5
# Completed 285 games, 406 rewards, 95638 frames, score 0, max score 5
# Completed 286 games, 407 rewards, 95819 frames, score 0, max score 5
# Completed 287 games, 408 rewards, 96073 frames, score 0, max score 5
# Completed 288 games, 411 rewards, 96822 frames, score 2, max score 5
# Completed 289 games, 412 rewards, 97030 frames, score 0, max score 5
# Completed 290 games, 415 rewards, 97445 frames, score 2, max score 5
# Completed 291 games, 416 rewards, 97626 frames, score 0, max score 5
# Completed 292 games, 420 rewards, 98691 frames, score 3, max score 5
# Completed 293 games, 421 rewards, 98945 frames, score 0, max score 5
# Completed 294 games, 422 rewards, 99153 frames, score 0, max score 5
# Completed 295 games, 424 rewards, 99559 frames, score 1, max score 5
# Completed 296 games, 425 rewards, 99813 frames, score 0, max score 5
# Completed 297 games, 426 rewards, 100067 frames, score 0, max score 5
# Completed 298 games, 428 rewards, 100530 frames, score 1, max score 5
# Completed 299 games, 429 rewards, 100784 frames, score 0, max score 5
# Completed 300 games, 432 rewards, 101474 frames, score 2, max score 5
# Completed 301 games, 437 rewards, 102639 frames, score 4, max score 5
# Completed 302 games, 438 rewards, 102820 frames, score 0, max score 5
# Completed 303 games, 439 rewards, 103074 frames, score 0, max score 5
# Completed 304 games, 440 rewards, 103282 frames, score 0, max score 5
# Completed 305 games, 441 rewards, 103536 frames, score 0, max score 5
# Completed 306 games, 442 rewards, 103744 frames, score 0, max score 5
# Completed 307 games, 443 rewards, 103952 frames, score 0, max score 5
# Completed 308 games, 444 rewards, 104160 frames, score 0, max score 5
# Completed 309 games, 445 rewards, 104341 frames, score 0, max score 5
# Completed 310 games, 446 rewards, 104595 frames, score 0, max score 5
# Completed 311 games, 448 rewards, 105146 frames, score 1, max score 5
# Completed 312 games, 450 rewards, 106065 frames, score 1, max score 5
# Completed 313 games, 451 rewards, 106273 frames, score 0, max score 5
# Completed 314 games, 453 rewards, 106935 frames, score 1, max score 5
# Completed 315 games, 454 rewards, 107143 frames, score 0, max score 5
# Completed 316 games, 456 rewards, 107603 frames, score 1, max score 5
# Completed 317 games, 459 rewards, 108466 frames, score 2, max score 5
# Completed 318 games, 461 rewards, 109068 frames, score 1, max score 5
# Completed 319 games, 462 rewards, 109249 frames, score 0, max score 5
# Completed 320 games, 465 rewards, 109980 frames, score 2, max score 5
# Completed 321 games, 466 rewards, 110161 frames, score 0, max score 5
# Completed 322 games, 467 rewards, 110342 frames, score 0, max score 5
# Completed 323 games, 468 rewards, 110523 frames, score 0, max score 5
# Completed 324 games, 472 rewards, 111630 frames, score 3, max score 5
# Completed 325 games, 473 rewards, 111838 frames, score 0, max score 5
# Completed 326 games, 478 rewards, 112817 frames, score 4, max score 5
# Completed 327 games, 479 rewards, 113071 frames, score 0, max score 5
# Completed 328 games, 480 rewards, 113325 frames, score 0, max score 5
# Completed 329 games, 481 rewards, 113533 frames, score 0, max score 5
# Completed 330 games, 482 rewards, 113787 frames, score 0, max score 5
# Completed 331 games, 483 rewards, 114041 frames, score 0, max score 5
# Completed 332 games, 484 rewards, 114249 frames, score 0, max score 5
# Completed 333 games, 485 rewards, 114503 frames, score 0, max score 5
# Completed 334 games, 487 rewards, 115093 frames, score 1, max score 5
# Completed 335 games, 488 rewards, 115347 frames, score 0, max score 5
# Completed 336 games, 491 rewards, 116490 frames, score 2, max score 5
# Completed 337 games, 494 rewards, 117732 frames, score 2, max score 5
# Completed 338 games, 496 rewards, 118394 frames, score 1, max score 5
# Completed 339 games, 499 rewards, 119358 frames, score 2, max score 5
# Completed 340 games, 500 rewards, 119566 frames, score 0, max score 5
# The number of games played was 342
# The number of rewards was 500
# The size of each returned Q-matrix was (4000, 3)

# %% [markdown]
# The returned value of `q_states` is a list of 4000x3 numpy arrays (20 states, 3 actions).  The list contains `m_rewards` of these. We want to convert it into something that matplotlib can plot.

# %%
import numpy as np

Q = np.array([np.reshape(q,-1) for q in q_states])
print('Q is now of shape',Q.shape)
print('the max absolute value of Q is ',np.amax(abs(Q)))
# Out:
# Q is now of shape (500, 12000)
# the max absolute value of Q is  2.091686086158862

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,6),layout='tight')
ax = [ fig.add_subplot(2,1,x) for x in range(1,3) ]
ax[0].plot(np.arange(0,len(q_states)),Q)
ax[0].set_title('Q values of all states')
ax[1].plot(np.arange(0,len(q_states)),q_achieved)
ax[1].set_title('Q values of state achieved at each time')
ax[1].set_ylabel('Reward number')
# Out:
# Text(0, 0.5, 'Reward number')

# %% [markdown]
# OK, now let's try running it for a much longer period -- say, 5000 complete games.  We won't ask it to print out any states this time.

# %%
scores, q_achieved, q_states = pong_game.run(m_games=5000, states=[])

print('The number of games played was',len(scores))
print('The number of video frames was',len(q_states))
print('The size of each returned Q-matrix was',q_states[0].shape)
# Out:
# Completed 0 games, 2 rewards, 438 frames, score 1, max score 5
# Completed 1 games, 3 rewards, 619 frames, score 0, max score 5
# Completed 2 games, 4 rewards, 873 frames, score 0, max score 5
# Completed 3 games, 5 rewards, 1081 frames, score 0, max score 5
# Completed 4 games, 7 rewards, 1683 frames, score 1, max score 5
# Completed 5 games, 9 rewards, 2081 frames, score 1, max score 5
# Completed 6 games, 16 rewards, 3451 frames, score 6, max score 6
# Completed 7 games, 17 rewards, 3632 frames, score 0, max score 6
# Completed 8 games, 21 rewards, 4292 frames, score 3, max score 6
# Completed 9 games, 23 rewards, 4675 frames, score 1, max score 6
# Completed 10 games, 24 rewards, 4883 frames, score 0, max score 6
# Completed 11 games, 25 rewards, 5064 frames, score 0, max score 6
# Completed 12 games, 26 rewards, 5245 frames, score 0, max score 6
# Completed 13 games, 27 rewards, 5426 frames, score 0, max score 6
# Completed 14 games, 28 rewards, 5680 frames, score 0, max score 6
# Completed 15 games, 31 rewards, 6272 frames, score 2, max score 6
# Completed 16 games, 32 rewards, 6526 frames, score 0, max score 6
# Completed 17 games, 33 rewards, 6734 frames, score 0, max score 6
# Completed 18 games, 34 rewards, 6942 frames, score 0, max score 6
# Completed 19 games, 35 rewards, 7123 frames, score 0, max score 6
# Completed 20 games, 36 rewards, 7377 frames, score 0, max score 6
# Completed 21 games, 39 rewards, 8021 frames, score 2, max score 6
# Completed 22 games, 41 rewards, 8419 frames, score 1, max score 6
# Completed 23 games, 44 rewards, 8995 frames, score 2, max score 6
# Completed 24 games, 47 rewards, 9482 frames, score 2, max score 6
# Completed 25 games, 51 rewards, 10694 frames, score 3, max score 6
# Completed 26 games, 54 rewards, 11345 frames, score 2, max score 6
# Completed 27 games, 55 rewards, 11599 frames, score 0, max score 6
# Completed 28 games, 56 rewards, 11780 frames, score 0, max score 6
# Completed 29 games, 57 rewards, 12034 frames, score 0, max score 6
# Completed 30 games, 58 rewards, 12242 frames, score 0, max score 6
# Completed 31 games, 60 rewards, 12609 frames, score 1, max score 6
# Completed 32 games, 62 rewards, 12976 frames, score 1, max score 6
# Completed 33 games, 63 rewards, 13230 frames, score 0, max score 6
# Completed 34 games, 64 rewards, 13411 frames, score 0, max score 6
# Completed 35 games, 65 rewards, 13592 frames, score 0, max score 6
# Completed 36 games, 66 rewards, 13773 frames, score 0, max score 6
# Completed 37 games, 67 rewards, 13954 frames, score 0, max score 6
# Completed 38 games, 73 rewards, 17957 frames, score 5, max score 6
# Completed 39 games, 75 rewards, 18368 frames, score 1, max score 6
# Completed 40 games, 76 rewards, 18576 frames, score 0, max score 6
# Completed 41 games, 78 rewards, 18990 frames, score 1, max score 6
# Completed 42 games, 79 rewards, 19244 frames, score 0, max score 6
# Completed 43 games, 80 rewards, 19452 frames, score 0, max score 6
# Completed 44 games, 82 rewards, 19858 frames, score 1, max score 6
# Completed 45 games, 83 rewards, 20112 frames, score 0, max score 6
# Completed 46 games, 84 rewards, 20293 frames, score 0, max score 6
# Completed 47 games, 86 rewards, 20725 frames, score 1, max score 6
# Completed 48 games, 87 rewards, 20906 frames, score 0, max score 6
# Completed 49 games, 88 rewards, 21087 frames, score 0, max score 6
# Completed 50 games, 92 rewards, 22795 frames, score 3, max score 6
# Completed 51 games, 95 rewards, 23336 frames, score 2, max score 6
# Completed 52 games, 96 rewards, 23517 frames, score 0, max score 6
# Completed 53 games, 97 rewards, 23698 frames, score 0, max score 6
# Completed 54 games, 99 rewards, 24195 frames, score 1, max score 6
# Completed 55 games, 100 rewards, 24376 frames, score 0, max score 6
# Completed 56 games, 101 rewards, 24584 frames, score 0, max score 6
# Completed 57 games, 102 rewards, 24792 frames, score 0, max score 6
# Completed 58 games, 108 rewards, 26309 frames, score 5, max score 6
# Completed 59 games, 109 rewards, 26563 frames, score 0, max score 6
# Completed 60 games, 113 rewards, 27412 frames, score 3, max score 6
# Completed 61 games, 115 rewards, 27963 frames, score 1, max score 6
# Completed 62 games, 116 rewards, 28144 frames, score 0, max score 6
# Completed 63 games, 117 rewards, 28325 frames, score 0, max score 6
# Completed 64 games, 118 rewards, 28533 frames, score 0, max score 6
# Completed 65 games, 123 rewards, 29755 frames, score 4, max score 6
# Completed 66 games, 124 rewards, 29963 frames, score 0, max score 6
# Completed 67 games, 131 rewards, 31277 frames, score 6, max score 6
# Completed 68 games, 132 rewards, 31531 frames, score 0, max score 6
# Completed 69 games, 133 rewards, 31712 frames, score 0, max score 6
# Completed 70 games, 134 rewards, 31966 frames, score 0, max score 6
# Completed 71 games, 136 rewards, 32403 frames, score 1, max score 6
# Completed 72 games, 137 rewards, 32584 frames, score 0, max score 6
# Completed 73 games, 138 rewards, 32765 frames, score 0, max score 6
# Completed 74 games, 140 rewards, 33157 frames, score 1, max score 6
# Completed 75 games, 141 rewards, 33411 frames, score 0, max score 6
# Completed 76 games, 143 rewards, 33794 frames, score 1, max score 6
# Completed 77 games, 144 rewards, 33975 frames, score 0, max score 6
# Completed 78 games, 145 rewards, 34156 frames, score 0, max score 6
# Completed 79 games, 148 rewards, 35041 frames, score 2, max score 6
# Completed 80 games, 149 rewards, 35295 frames, score 0, max score 6
# Completed 81 games, 150 rewards, 35503 frames, score 0, max score 6
# Completed 82 games, 151 rewards, 35684 frames, score 0, max score 6
# Completed 83 games, 152 rewards, 35892 frames, score 0, max score 6
# Completed 84 games, 153 rewards, 36073 frames, score 0, max score 6
# Completed 85 games, 156 rewards, 36620 frames, score 2, max score 6
# Completed 86 games, 157 rewards, 36801 frames, score 0, max score 6
# Completed 87 games, 158 rewards, 37055 frames, score 0, max score 6
# Completed 88 games, 161 rewards, 37716 frames, score 2, max score 6
# Completed 89 games, 164 rewards, 38669 frames, score 2, max score 6
# Completed 90 games, 165 rewards, 38877 frames, score 0, max score 6
# Completed 91 games, 168 rewards, 39547 frames, score 2, max score 6
# Completed 92 games, 169 rewards, 39728 frames, score 0, max score 6
# Completed 93 games, 170 rewards, 39909 frames, score 0, max score 6
# Completed 94 games, 171 rewards, 40090 frames, score 0, max score 6
# Completed 95 games, 172 rewards, 40271 frames, score 0, max score 6
# Completed 96 games, 174 rewards, 40861 frames, score 1, max score 6
# Completed 97 games, 175 rewards, 41042 frames, score 0, max score 6
# Completed 98 games, 176 rewards, 41250 frames, score 0, max score 6
# Completed 99 games, 177 rewards, 41431 frames, score 0, max score 6
# Completed 100 games, 179 rewards, 41772 frames, score 1, max score 6
# Completed 101 games, 180 rewards, 41953 frames, score 0, max score 6
# Completed 102 games, 181 rewards, 42134 frames, score 0, max score 6
# Completed 103 games, 182 rewards, 42315 frames, score 0, max score 6
# Completed 104 games, 184 rewards, 42752 frames, score 1, max score 6
# Completed 105 games, 186 rewards, 43342 frames, score 1, max score 6
# Completed 106 games, 188 rewards, 43747 frames, score 1, max score 6
# Completed 107 games, 190 rewards, 44184 frames, score 1, max score 6
# Completed 108 games, 191 rewards, 44438 frames, score 0, max score 6
# Completed 109 games, 192 rewards, 44692 frames, score 0, max score 6
# Completed 110 games, 193 rewards, 44873 frames, score 0, max score 6
# Completed 111 games, 196 rewards, 46520 frames, score 2, max score 6
# Completed 112 games, 198 rewards, 46926 frames, score 1, max score 6
# Completed 113 games, 199 rewards, 47107 frames, score 0, max score 6
# Completed 114 games, 200 rewards, 47288 frames, score 0, max score 6
# Completed 115 games, 201 rewards, 47469 frames, score 0, max score 6
# Completed 116 games, 202 rewards, 47723 frames, score 0, max score 6
# Completed 117 games, 203 rewards, 47977 frames, score 0, max score 6
# Completed 118 games, 207 rewards, 48754 frames, score 3, max score 6
# Completed 119 games, 208 rewards, 48935 frames, score 0, max score 6
# Completed 120 games, 210 rewards, 49372 frames, score 1, max score 6
# Completed 121 games, 212 rewards, 49777 frames, score 1, max score 6
# Completed 122 games, 213 rewards, 49985 frames, score 0, max score 6
# Completed 123 games, 214 rewards, 50239 frames, score 0, max score 6
# Completed 124 games, 216 rewards, 50901 frames, score 1, max score 6
# Completed 125 games, 221 rewards, 52106 frames, score 4, max score 6
# Completed 126 games, 224 rewards, 52854 frames, score 2, max score 6
# Completed 127 games, 225 rewards, 53108 frames, score 0, max score 6
# Completed 128 games, 226 rewards, 53289 frames, score 0, max score 6
# Completed 129 games, 229 rewards, 54265 frames, score 2, max score 6
# Completed 130 games, 230 rewards, 54519 frames, score 0, max score 6
# Completed 131 games, 235 rewards, 55493 frames, score 4, max score 6
# Completed 132 games, 236 rewards, 55701 frames, score 0, max score 6
# Completed 133 games, 238 rewards, 56099 frames, score 1, max score 6
# Completed 134 games, 239 rewards, 56307 frames, score 0, max score 6
# Completed 135 games, 241 rewards, 56659 frames, score 1, max score 6
# Completed 136 games, 242 rewards, 56913 frames, score 0, max score 6
# Completed 137 games, 244 rewards, 57401 frames, score 1, max score 6
# Completed 138 games, 245 rewards, 57655 frames, score 0, max score 6
# Completed 139 games, 247 rewards, 58245 frames, score 1, max score 6
# Completed 140 games, 249 rewards, 58650 frames, score 1, max score 6
# Completed 141 games, 251 rewards, 59077 frames, score 1, max score 6
# Completed 142 games, 252 rewards, 59258 frames, score 0, max score 6
# Completed 143 games, 256 rewards, 60469 frames, score 3, max score 6
# Completed 144 games, 257 rewards, 60723 frames, score 0, max score 6
# Completed 145 games, 258 rewards, 60977 frames, score 0, max score 6
# Completed 146 games, 259 rewards, 61231 frames, score 0, max score 6
# Completed 147 games, 260 rewards, 61412 frames, score 0, max score 6
# Completed 148 games, 262 rewards, 61875 frames, score 1, max score 6
# Completed 149 games, 263 rewards, 62083 frames, score 0, max score 6
# Completed 150 games, 264 rewards, 62337 frames, score 0, max score 6
# Completed 151 games, 266 rewards, 62834 frames, score 1, max score 6
# Completed 152 games, 267 rewards, 63015 frames, score 0, max score 6
# Completed 153 games, 268 rewards, 63269 frames, score 0, max score 6
# Completed 154 games, 270 rewards, 63803 frames, score 1, max score 6
# Completed 155 games, 273 rewards, 64294 frames, score 2, max score 6
# Completed 156 games, 274 rewards, 64475 frames, score 0, max score 6
# Completed 157 games, 276 rewards, 64972 frames, score 1, max score 6
# Completed 158 games, 278 rewards, 65340 frames, score 1, max score 6
# Completed 159 games, 279 rewards, 65521 frames, score 0, max score 6
# Completed 160 games, 280 rewards, 65729 frames, score 0, max score 6
# Completed 161 games, 284 rewards, 66772 frames, score 3, max score 6
# Completed 162 games, 288 rewards, 67423 frames, score 3, max score 6
# Completed 163 games, 289 rewards, 67631 frames, score 0, max score 6
# Completed 164 games, 292 rewards, 68260 frames, score 2, max score 6
# Completed 165 games, 294 rewards, 68723 frames, score 1, max score 6
# Completed 166 games, 295 rewards, 68977 frames, score 0, max score 6
# Completed 167 games, 296 rewards, 69158 frames, score 0, max score 6
# Completed 168 games, 297 rewards, 69412 frames, score 0, max score 6
# Completed 169 games, 298 rewards, 69666 frames, score 0, max score 6
# Completed 170 games, 299 rewards, 69920 frames, score 0, max score 6
# Completed 171 games, 301 rewards, 70285 frames, score 1, max score 6
# Completed 172 games, 302 rewards, 70466 frames, score 0, max score 6
# Completed 173 games, 303 rewards, 70647 frames, score 0, max score 6
# Completed 174 games, 304 rewards, 70901 frames, score 0, max score 6
# Completed 175 games, 305 rewards, 71109 frames, score 0, max score 6
# Completed 176 games, 306 rewards, 71363 frames, score 0, max score 6
# Completed 177 games, 309 rewards, 72021 frames, score 2, max score 6
# Completed 178 games, 310 rewards, 72202 frames, score 0, max score 6
# Completed 179 games, 314 rewards, 73149 frames, score 3, max score 6
# Completed 180 games, 316 rewards, 73811 frames, score 1, max score 6
# Completed 181 games, 317 rewards, 74065 frames, score 0, max score 6
# Completed 182 games, 318 rewards, 74319 frames, score 0, max score 6
# Completed 183 games, 320 rewards, 74981 frames, score 1, max score 6
# Completed 184 games, 321 rewards, 75162 frames, score 0, max score 6
# Completed 185 games, 323 rewards, 75764 frames, score 1, max score 6
# Completed 186 games, 324 rewards, 75945 frames, score 0, max score 6
# Completed 187 games, 326 rewards, 76328 frames, score 1, max score 6
# Completed 188 games, 327 rewards, 76582 frames, score 0, max score 6
# Completed 189 games, 329 rewards, 77184 frames, score 1, max score 6
# Completed 190 games, 332 rewards, 77664 frames, score 2, max score 6
# Completed 191 games, 333 rewards, 77918 frames, score 0, max score 6
# Completed 192 games, 334 rewards, 78099 frames, score 0, max score 6
# Completed 193 games, 335 rewards, 78307 frames, score 0, max score 6
# Completed 194 games, 336 rewards, 78515 frames, score 0, max score 6
# Completed 195 games, 341 rewards, 79584 frames, score 4, max score 6
# Completed 196 games, 342 rewards, 79838 frames, score 0, max score 6
# Completed 197 games, 343 rewards, 80092 frames, score 0, max score 6
# Completed 198 games, 344 rewards, 80273 frames, score 0, max score 6
# Completed 199 games, 345 rewards, 80481 frames, score 0, max score 6
# Completed 200 games, 346 rewards, 80689 frames, score 0, max score 6
# Completed 201 games, 347 rewards, 80897 frames, score 0, max score 6
# Completed 202 games, 348 rewards, 81078 frames, score 0, max score 6
# Completed 203 games, 349 rewards, 81259 frames, score 0, max score 6
# Completed 204 games, 350 rewards, 81440 frames, score 0, max score 6
# Completed 205 games, 351 rewards, 81694 frames, score 0, max score 6
# Completed 206 games, 354 rewards, 82304 frames, score 2, max score 6
# Completed 207 games, 355 rewards, 82485 frames, score 0, max score 6
# Completed 208 games, 356 rewards, 82739 frames, score 0, max score 6
# Completed 209 games, 358 rewards, 83236 frames, score 1, max score 6
# Completed 210 games, 359 rewards, 83490 frames, score 0, max score 6
# Completed 211 games, 361 rewards, 84041 frames, score 1, max score 6
# Completed 212 games, 363 rewards, 84592 frames, score 1, max score 6
# Completed 213 games, 365 rewards, 85326 frames, score 1, max score 6
# Completed 214 games, 369 rewards, 86285 frames, score 3, max score 6
# Completed 215 games, 370 rewards, 86493 frames, score 0, max score 6
# Completed 216 games, 373 rewards, 87140 frames, score 2, max score 6
# Completed 217 games, 379 rewards, 91295 frames, score 5, max score 6
# Completed 218 games, 380 rewards, 91476 frames, score 0, max score 6
# Completed 219 games, 384 rewards, 92234 frames, score 3, max score 6
# Completed 220 games, 385 rewards, 92488 frames, score 0, max score 6
# Completed 221 games, 386 rewards, 92742 frames, score 0, max score 6
# Completed 222 games, 388 rewards, 93179 frames, score 1, max score 6
# Completed 223 games, 389 rewards, 93387 frames, score 0, max score 6
# Completed 224 games, 391 rewards, 93779 frames, score 1, max score 6
# Completed 225 games, 395 rewards, 95386 frames, score 3, max score 6
# Completed 226 games, 397 rewards, 96048 frames, score 1, max score 6
# Completed 227 games, 400 rewards, 96747 frames, score 2, max score 6
# Completed 228 games, 404 rewards, 97518 frames, score 3, max score 6
# Completed 229 games, 406 rewards, 98030 frames, score 1, max score 6
# Completed 230 games, 407 rewards, 98238 frames, score 0, max score 6
# Completed 231 games, 408 rewards, 98492 frames, score 0, max score 6
# Completed 232 games, 409 rewards, 98746 frames, score 0, max score 6
# Completed 233 games, 416 rewards, 100243 frames, score 6, max score 6
# Completed 234 games, 418 rewards, 100977 frames, score 1, max score 6
# Completed 235 games, 420 rewards, 101414 frames, score 1, max score 6
# Completed 236 games, 424 rewards, 102851 frames, score 3, max score 6
# Completed 237 games, 425 rewards, 103105 frames, score 0, max score 6
# Completed 238 games, 426 rewards, 103313 frames, score 0, max score 6
# Completed 239 games, 428 rewards, 103680 frames, score 1, max score 6
# Completed 240 games, 433 rewards, 105381 frames, score 4, max score 6
# Completed 241 games, 435 rewards, 106043 frames, score 1, max score 6
# Completed 242 games, 437 rewards, 106426 frames, score 1, max score 6
# Completed 243 games, 445 rewards, 107700 frames, score 7, max score 7
# Completed 244 games, 447 rewards, 108197 frames, score 1, max score 7
# Completed 245 games, 448 rewards, 108451 frames, score 0, max score 7
# Completed 246 games, 449 rewards, 108632 frames, score 0, max score 7
# Completed 247 games, 453 rewards, 109661 frames, score 3, max score 7
# Completed 248 games, 454 rewards, 109869 frames, score 0, max score 7
# Completed 249 games, 456 rewards, 110788 frames, score 1, max score 7
# Completed 250 games, 460 rewards, 111651 frames, score 3, max score 7
# Completed 251 games, 462 rewards, 112253 frames, score 1, max score 7
# Completed 252 games, 464 rewards, 112804 frames, score 1, max score 7
# Completed 253 games, 465 rewards, 112985 frames, score 0, max score 7
# Completed 254 games, 466 rewards, 113166 frames, score 0, max score 7
# Completed 255 games, 468 rewards, 113629 frames, score 1, max score 7
# Completed 256 games, 469 rewards, 113883 frames, score 0, max score 7
# Completed 257 games, 470 rewards, 114091 frames, score 0, max score 7
# Completed 258 games, 472 rewards, 114432 frames, score 1, max score 7
# Completed 259 games, 474 rewards, 114773 frames, score 1, max score 7
# Completed 260 games, 475 rewards, 114954 frames, score 0, max score 7
# Completed 261 games, 476 rewards, 115135 frames, score 0, max score 7
# Completed 262 games, 481 rewards, 116240 frames, score 4, max score 7
# Completed 263 games, 482 rewards, 116448 frames, score 0, max score 7
# Completed 264 games, 483 rewards, 116656 frames, score 0, max score 7
# Completed 265 games, 485 rewards, 117070 frames, score 1, max score 7
# Completed 266 games, 486 rewards, 117251 frames, score 0, max score 7
# Completed 267 games, 487 rewards, 117459 frames, score 0, max score 7
# Completed 268 games, 491 rewards, 118675 frames, score 3, max score 7
# Completed 269 games, 493 rewards, 119226 frames, score 1, max score 7
# Completed 270 games, 496 rewards, 119989 frames, score 2, max score 7
# Completed 271 games, 497 rewards, 120197 frames, score 0, max score 7
# Completed 272 games, 498 rewards, 120378 frames, score 0, max score 7
# Completed 273 games, 499 rewards, 120586 frames, score 0, max score 7
# Completed 274 games, 501 rewards, 120991 frames, score 1, max score 7
# Completed 275 games, 503 rewards, 121428 frames, score 1, max score 7
# Completed 276 games, 504 rewards, 121636 frames, score 0, max score 7
# Completed 277 games, 506 rewards, 122187 frames, score 1, max score 7
# Completed 278 games, 508 rewards, 122601 frames, score 1, max score 7
# Completed 279 games, 509 rewards, 122855 frames, score 0, max score 7
# Completed 280 games, 510 rewards, 123036 frames, score 0, max score 7
# Completed 281 games, 512 rewards, 123434 frames, score 1, max score 7
# Completed 282 games, 514 rewards, 123931 frames, score 1, max score 7
# Completed 283 games, 515 rewards, 124112 frames, score 0, max score 7
# Completed 284 games, 516 rewards, 124320 frames, score 0, max score 7
# Completed 285 games, 518 rewards, 124726 frames, score 1, max score 7
# Completed 286 games, 519 rewards, 124980 frames, score 0, max score 7
# Completed 287 games, 520 rewards, 125188 frames, score 0, max score 7
# Completed 288 games, 523 rewards, 125885 frames, score 2, max score 7
# Completed 289 games, 528 rewards, 127299 frames, score 4, max score 7
# Completed 290 games, 531 rewards, 127805 frames, score 2, max score 7
# Completed 291 games, 533 rewards, 128233 frames, score 1, max score 7
# Completed 292 games, 534 rewards, 128487 frames, score 0, max score 7
# Completed 293 games, 535 rewards, 128668 frames, score 0, max score 7
# Completed 294 games, 540 rewards, 130569 frames, score 4, max score 7
# Completed 295 games, 544 rewards, 131726 frames, score 3, max score 7
# Completed 296 games, 550 rewards, 134621 frames, score 5, max score 7
# Completed 297 games, 551 rewards, 134875 frames, score 0, max score 7
# Completed 298 games, 553 rewards, 135426 frames, score 1, max score 7
# Completed 299 games, 554 rewards, 135680 frames, score 0, max score 7
# Completed 300 games, 555 rewards, 135934 frames, score 0, max score 7
# Completed 301 games, 558 rewards, 136641 frames, score 2, max score 7
# Completed 302 games, 560 rewards, 137175 frames, score 1, max score 7
# Completed 303 games, 565 rewards, 139319 frames, score 4, max score 7
# Completed 304 games, 566 rewards, 139573 frames, score 0, max score 7
# Completed 305 games, 567 rewards, 139827 frames, score 0, max score 7
# Completed 306 games, 568 rewards, 140008 frames, score 0, max score 7
# Completed 307 games, 569 rewards, 140189 frames, score 0, max score 7
# Completed 308 games, 572 rewards, 141143 frames, score 2, max score 7
# Completed 309 games, 573 rewards, 141397 frames, score 0, max score 7
# Completed 310 games, 574 rewards, 141651 frames, score 0, max score 7
# Completed 311 games, 576 rewards, 142057 frames, score 1, max score 7
# Completed 312 games, 579 rewards, 142668 frames, score 2, max score 7
# Completed 313 games, 581 rewards, 143330 frames, score 1, max score 7
# Completed 314 games, 591 rewards, 145078 frames, score 9, max score 9
# Completed 315 games, 592 rewards, 145286 frames, score 0, max score 9
# Completed 316 games, 595 rewards, 146072 frames, score 2, max score 9
# Completed 317 games, 596 rewards, 146280 frames, score 0, max score 9
# Completed 318 games, 599 rewards, 146991 frames, score 2, max score 9
# Completed 319 games, 601 rewards, 147488 frames, score 1, max score 9
# Completed 320 games, 603 rewards, 147976 frames, score 1, max score 9
# Completed 321 games, 604 rewards, 148157 frames, score 0, max score 9
# Completed 322 games, 609 rewards, 149572 frames, score 4, max score 9
# Completed 323 games, 610 rewards, 149780 frames, score 0, max score 9
# Completed 324 games, 611 rewards, 149961 frames, score 0, max score 9
# Completed 325 games, 612 rewards, 150169 frames, score 0, max score 9
# Completed 326 games, 613 rewards, 150423 frames, score 0, max score 9
# Completed 327 games, 615 rewards, 151013 frames, score 1, max score 9
# Completed 328 games, 619 rewards, 152135 frames, score 3, max score 9
# Completed 329 games, 626 rewards, 154126 frames, score 6, max score 9
# Completed 330 games, 627 rewards, 154380 frames, score 0, max score 9
# Completed 331 games, 628 rewards, 154634 frames, score 0, max score 9
# Completed 332 games, 629 rewards, 154842 frames, score 0, max score 9
# Completed 333 games, 632 rewards, 155445 frames, score 2, max score 9
# Completed 334 games, 635 rewards, 156409 frames, score 2, max score 9
# Completed 335 games, 638 rewards, 157090 frames, score 2, max score 9
# Completed 336 games, 641 rewards, 158058 frames, score 2, max score 9
# Completed 337 games, 643 rewards, 158495 frames, score 1, max score 9
# Completed 338 games, 645 rewards, 158983 frames, score 1, max score 9
# Completed 339 games, 647 rewards, 159389 frames, score 1, max score 9
# Completed 340 games, 649 rewards, 159886 frames, score 1, max score 9
# Completed 341 games, 652 rewards, 160474 frames, score 2, max score 9
# Completed 342 games, 655 rewards, 161180 frames, score 2, max score 9
# Completed 343 games, 656 rewards, 161388 frames, score 0, max score 9
# Completed 344 games, 657 rewards, 161569 frames, score 0, max score 9
# Completed 345 games, 658 rewards, 161823 frames, score 0, max score 9
# Completed 346 games, 659 rewards, 162031 frames, score 0, max score 9
# Completed 347 games, 660 rewards, 162212 frames, score 0, max score 9
# Completed 348 games, 663 rewards, 163746 frames, score 2, max score 9
# Completed 349 games, 664 rewards, 163954 frames, score 0, max score 9
# Completed 350 games, 665 rewards, 164208 frames, score 0, max score 9
# Completed 351 games, 666 rewards, 164416 frames, score 0, max score 9
# Completed 352 games, 667 rewards, 164597 frames, score 0, max score 9
# Completed 353 games, 674 rewards, 166155 frames, score 6, max score 9
# Completed 354 games, 675 rewards, 166363 frames, score 0, max score 9
# Completed 355 games, 676 rewards, 166544 frames, score 0, max score 9
# Completed 356 games, 678 rewards, 166949 frames, score 1, max score 9
# Completed 357 games, 679 rewards, 167203 frames, score 0, max score 9
# Completed 358 games, 687 rewards, 169046 frames, score 7, max score 9
# Completed 359 games, 689 rewards, 169597 frames, score 1, max score 9
# Completed 360 games, 693 rewards, 171310 frames, score 3, max score 9
# Completed 361 games, 695 rewards, 171861 frames, score 1, max score 9
# Completed 362 games, 698 rewards, 172469 frames, score 2, max score 9
# Completed 363 games, 699 rewards, 172677 frames, score 0, max score 9
# Completed 364 games, 700 rewards, 172858 frames, score 0, max score 9
# Completed 365 games, 705 rewards, 173863 frames, score 4, max score 9
# Completed 366 games, 706 rewards, 174044 frames, score 0, max score 9
# Completed 367 games, 707 rewards, 174298 frames, score 0, max score 9
# Completed 368 games, 708 rewards, 174506 frames, score 0, max score 9
# Completed 369 games, 709 rewards, 174760 frames, score 0, max score 9
# Completed 370 games, 710 rewards, 175014 frames, score 0, max score 9
# Completed 371 games, 711 rewards, 175195 frames, score 0, max score 9
# Completed 372 games, 714 rewards, 176842 frames, score 2, max score 9
# Completed 373 games, 717 rewards, 177628 frames, score 2, max score 9
# Completed 374 games, 722 rewards, 180678 frames, score 4, max score 9
# Completed 375 games, 723 rewards, 180859 frames, score 0, max score 9
# Completed 376 games, 726 rewards, 181509 frames, score 2, max score 9
# Completed 377 games, 727 rewards, 181763 frames, score 0, max score 9
# Completed 378 games, 728 rewards, 181944 frames, score 0, max score 9
# Completed 379 games, 731 rewards, 182435 frames, score 2, max score 9
# Completed 380 games, 732 rewards, 182689 frames, score 0, max score 9
# Completed 381 games, 734 rewards, 183126 frames, score 1, max score 9
# Completed 382 games, 737 rewards, 184079 frames, score 2, max score 9
# Completed 383 games, 742 rewards, 185463 frames, score 4, max score 9
# Completed 384 games, 743 rewards, 185717 frames, score 0, max score 9
# Completed 385 games, 746 rewards, 186465 frames, score 2, max score 9
# Completed 386 games, 750 rewards, 187102 frames, score 3, max score 9
# Completed 387 games, 751 rewards, 187283 frames, score 0, max score 9
# Completed 388 games, 759 rewards, 189453 frames, score 7, max score 9
# Completed 389 games, 764 rewards, 190646 frames, score 4, max score 9
# Completed 390 games, 765 rewards, 190854 frames, score 0, max score 9
# Completed 391 games, 774 rewards, 196224 frames, score 8, max score 9
# Completed 392 games, 775 rewards, 196432 frames, score 0, max score 9
# Completed 393 games, 776 rewards, 196613 frames, score 0, max score 9
# Completed 394 games, 777 rewards, 196794 frames, score 0, max score 9
# Completed 395 games, 779 rewards, 197161 frames, score 1, max score 9
# Completed 396 games, 785 rewards, 198012 frames, score 5, max score 9
# Completed 397 games, 786 rewards, 198266 frames, score 0, max score 9
# Completed 398 games, 788 rewards, 198778 frames, score 1, max score 9
# Completed 399 games, 792 rewards, 200315 frames, score 3, max score 9
# Completed 400 games, 794 rewards, 200683 frames, score 1, max score 9
# Completed 401 games, 798 rewards, 201727 frames, score 3, max score 9
# Completed 402 games, 801 rewards, 202557 frames, score 2, max score 9
# Completed 403 games, 802 rewards, 202811 frames, score 0, max score 9
# Completed 404 games, 804 rewards, 203308 frames, score 1, max score 9
# Completed 405 games, 806 rewards, 203970 frames, score 1, max score 9
# Completed 406 games, 809 rewards, 204573 frames, score 2, max score 9
# Completed 407 games, 810 rewards, 204827 frames, score 0, max score 9
# Completed 408 games, 816 rewards, 205864 frames, score 5, max score 9
# Completed 409 games, 818 rewards, 206324 frames, score 1, max score 9
# Completed 410 games, 821 rewards, 207035 frames, score 2, max score 9
# Completed 411 games, 823 rewards, 207387 frames, score 1, max score 9
# Completed 412 games, 824 rewards, 207641 frames, score 0, max score 9
# Completed 413 games, 825 rewards, 207895 frames, score 0, max score 9
# Completed 414 games, 828 rewards, 208657 frames, score 2, max score 9
# Completed 415 games, 829 rewards, 208865 frames, score 0, max score 9
# Completed 416 games, 832 rewards, 209555 frames, score 2, max score 9
# Completed 417 games, 837 rewards, 210413 frames, score 4, max score 9
# Completed 418 games, 839 rewards, 210827 frames, score 1, max score 9
# Completed 419 games, 841 rewards, 211210 frames, score 1, max score 9
# Completed 420 games, 842 rewards, 211464 frames, score 0, max score 9
# Completed 421 games, 844 rewards, 211832 frames, score 1, max score 9
# Completed 422 games, 845 rewards, 212086 frames, score 0, max score 9
# Completed 423 games, 848 rewards, 212854 frames, score 2, max score 9
# Completed 424 games, 851 rewards, 213808 frames, score 2, max score 9
# Completed 425 games, 856 rewards, 214760 frames, score 4, max score 9
# Completed 426 games, 857 rewards, 215014 frames, score 0, max score 9
# Completed 427 games, 858 rewards, 215222 frames, score 0, max score 9
# Completed 428 games, 860 rewards, 215620 frames, score 1, max score 9
# Completed 429 games, 861 rewards, 215874 frames, score 0, max score 9
# Completed 430 games, 866 rewards, 216955 frames, score 4, max score 9
# Completed 431 games, 874 rewards, 218943 frames, score 7, max score 9
# Completed 432 games, 876 rewards, 219341 frames, score 1, max score 9
# Completed 433 games, 880 rewards, 219969 frames, score 3, max score 9
# Completed 434 games, 881 rewards, 220223 frames, score 0, max score 9
# Completed 435 games, 882 rewards, 220431 frames, score 0, max score 9
# Completed 436 games, 889 rewards, 222834 frames, score 6, max score 9
# Completed 437 games, 890 rewards, 223015 frames, score 0, max score 9
# Completed 438 games, 893 rewards, 223675 frames, score 2, max score 9
# Completed 439 games, 894 rewards, 223929 frames, score 0, max score 9
# Completed 440 games, 900 rewards, 225067 frames, score 5, max score 9
# Completed 441 games, 912 rewards, 226904 frames, score 11, max score 11
# Completed 442 games, 916 rewards, 227972 frames, score 3, max score 11
# Completed 443 games, 918 rewards, 228340 frames, score 1, max score 11
# Completed 444 games, 922 rewards, 229254 frames, score 3, max score 11
# Completed 445 games, 923 rewards, 229462 frames, score 0, max score 11
# Completed 446 games, 924 rewards, 229716 frames, score 0, max score 11
# Completed 447 games, 926 rewards, 230450 frames, score 1, max score 11
# Completed 448 games, 927 rewards, 230631 frames, score 0, max score 11
# Completed 449 games, 929 rewards, 231091 frames, score 1, max score 11
# Completed 450 games, 935 rewards, 233143 frames, score 5, max score 11
# Completed 451 games, 937 rewards, 233745 frames, score 1, max score 11
# Completed 452 games, 942 rewards, 235800 frames, score 4, max score 11
# Completed 453 games, 943 rewards, 236054 frames, score 0, max score 11
# Completed 454 games, 944 rewards, 236308 frames, score 0, max score 11
# Completed 455 games, 946 rewards, 236714 frames, score 1, max score 11
# Completed 456 games, 951 rewards, 238364 frames, score 4, max score 11
# Completed 457 games, 953 rewards, 238716 frames, score 1, max score 11
# Completed 458 games, 955 rewards, 239318 frames, score 1, max score 11
# Completed 459 games, 956 rewards, 239572 frames, score 0, max score 11
# Completed 460 games, 958 rewards, 239986 frames, score 1, max score 11
# Completed 461 games, 964 rewards, 241612 frames, score 5, max score 11
# Completed 462 games, 970 rewards, 243372 frames, score 5, max score 11
# Completed 463 games, 971 rewards, 243580 frames, score 0, max score 11
# Completed 464 games, 972 rewards, 243761 frames, score 0, max score 11
# Completed 465 games, 975 rewards, 244487 frames, score 2, max score 11
# Completed 466 games, 978 rewards, 245071 frames, score 2, max score 11
# Completed 467 games, 983 rewards, 246048 frames, score 4, max score 11
# Completed 468 games, 984 rewards, 246256 frames, score 0, max score 11
# Completed 469 games, 987 rewards, 247119 frames, score 2, max score 11
# Completed 470 games, 989 rewards, 247616 frames, score 1, max score 11
# Completed 471 games, 994 rewards, 249043 frames, score 4, max score 11
# Completed 472 games, 995 rewards, 249297 frames, score 0, max score 11
# Completed 473 games, 999 rewards, 249989 frames, score 3, max score 11
# Completed 474 games, 1003 rewards, 250852 frames, score 3, max score 11
# Completed 475 games, 1006 rewards, 251372 frames, score 2, max score 11
# Completed 476 games, 1011 rewards, 252238 frames, score 4, max score 11
# Completed 477 games, 1012 rewards, 252446 frames, score 0, max score 11
# Completed 478 games, 1013 rewards, 252627 frames, score 0, max score 11
# Completed 479 games, 1016 rewards, 253512 frames, score 2, max score 11
# Completed 480 games, 1019 rewards, 254290 frames, score 2, max score 11
# Completed 481 games, 1023 rewards, 255305 frames, score 3, max score 11
# Completed 482 games, 1025 rewards, 255967 frames, score 1, max score 11
# Completed 483 games, 1027 rewards, 256335 frames, score 1, max score 11
# Completed 484 games, 1031 rewards, 257299 frames, score 3, max score 11
# Completed 485 games, 1034 rewards, 257915 frames, score 2, max score 11
# Completed 486 games, 1035 rewards, 258169 frames, score 0, max score 11
# Completed 487 games, 1036 rewards, 258350 frames, score 0, max score 11
# Completed 488 games, 1037 rewards, 258558 frames, score 0, max score 11
# Completed 489 games, 1040 rewards, 259872 frames, score 2, max score 11
# Completed 490 games, 1042 rewards, 260309 frames, score 1, max score 11
# Completed 491 games, 1047 rewards, 261117 frames, score 4, max score 11
# Completed 492 games, 1049 rewards, 261531 frames, score 1, max score 11
# Completed 493 games, 1054 rewards, 262581 frames, score 4, max score 11
# Completed 494 games, 1055 rewards, 262762 frames, score 0, max score 11
# Completed 495 games, 1056 rewards, 263016 frames, score 0, max score 11
# Completed 496 games, 1059 rewards, 264550 frames, score 2, max score 11
# Completed 497 games, 1062 rewards, 265246 frames, score 2, max score 11
# Completed 498 games, 1063 rewards, 265454 frames, score 0, max score 11
# Completed 499 games, 1070 rewards, 267295 frames, score 6, max score 11
# Completed 500 games, 1077 rewards, 269086 frames, score 6, max score 11
# Completed 501 games, 1079 rewards, 269546 frames, score 1, max score 11
# Completed 502 games, 1080 rewards, 269754 frames, score 0, max score 11
# Completed 503 games, 1084 rewards, 270969 frames, score 3, max score 11
# Completed 504 games, 1086 rewards, 271406 frames, score 1, max score 11
# Completed 505 games, 1087 rewards, 271587 frames, score 0, max score 11
# Completed 506 games, 1088 rewards, 271768 frames, score 0, max score 11
# Completed 507 games, 1089 rewards, 271976 frames, score 0, max score 11
# Completed 508 games, 1090 rewards, 272157 frames, score 0, max score 11
# Completed 509 games, 1094 rewards, 273119 frames, score 3, max score 11
# Completed 510 games, 1100 rewards, 274225 frames, score 5, max score 11
# Completed 511 games, 1102 rewards, 274630 frames, score 1, max score 11
# Completed 512 games, 1109 rewards, 279858 frames, score 6, max score 11
# Completed 513 games, 1115 rewards, 281246 frames, score 5, max score 11
# Completed 514 games, 1122 rewards, 282437 frames, score 6, max score 11
# Completed 515 games, 1123 rewards, 282691 frames, score 0, max score 11
# Completed 516 games, 1126 rewards, 283364 frames, score 2, max score 11
# Completed 517 games, 1127 rewards, 283545 frames, score 0, max score 11
# Completed 518 games, 1128 rewards, 283753 frames, score 0, max score 11
# Completed 519 games, 1129 rewards, 283961 frames, score 0, max score 11
# Completed 520 games, 1132 rewards, 285985 frames, score 2, max score 11
# Completed 521 games, 1137 rewards, 287355 frames, score 4, max score 11
# Completed 522 games, 1138 rewards, 287536 frames, score 0, max score 11
# Completed 523 games, 1139 rewards, 287717 frames, score 0, max score 11
# Completed 524 games, 1140 rewards, 287925 frames, score 0, max score 11
# Completed 525 games, 1145 rewards, 289861 frames, score 4, max score 11
# Completed 526 games, 1149 rewards, 290666 frames, score 3, max score 11
# Completed 527 games, 1150 rewards, 290847 frames, score 0, max score 11
# Completed 528 games, 1152 rewards, 291307 frames, score 1, max score 11
# Completed 529 games, 1153 rewards, 291515 frames, score 0, max score 11
# Completed 530 games, 1154 rewards, 291723 frames, score 0, max score 11
# Completed 531 games, 1155 rewards, 291904 frames, score 0, max score 11
# Completed 532 games, 1161 rewards, 293059 frames, score 5, max score 11
# Completed 533 games, 1162 rewards, 293313 frames, score 0, max score 11
# Completed 534 games, 1165 rewards, 293883 frames, score 2, max score 11
# Completed 535 games, 1171 rewards, 295067 frames, score 5, max score 11
# Completed 536 games, 1177 rewards, 297918 frames, score 5, max score 11
# Completed 537 games, 1179 rewards, 298452 frames, score 1, max score 11
# Completed 538 games, 1185 rewards, 300472 frames, score 5, max score 11
# Completed 539 games, 1198 rewards, 306681 frames, score 12, max score 12
# Completed 540 games, 1199 rewards, 306862 frames, score 0, max score 12
# Completed 541 games, 1202 rewards, 307399 frames, score 2, max score 12
# Completed 542 games, 1205 rewards, 308443 frames, score 2, max score 12
# Completed 543 games, 1206 rewards, 308624 frames, score 0, max score 12
# Completed 544 games, 1207 rewards, 308832 frames, score 0, max score 12
# Completed 545 games, 1211 rewards, 309809 frames, score 3, max score 12
# Completed 546 games, 1213 rewards, 310215 frames, score 1, max score 12
# Completed 547 games, 1215 rewards, 310582 frames, score 1, max score 12
# Completed 548 games, 1216 rewards, 310790 frames, score 0, max score 12
# Completed 549 games, 1219 rewards, 311334 frames, score 2, max score 12
# Completed 550 games, 1221 rewards, 311771 frames, score 1, max score 12
# Completed 551 games, 1224 rewards, 312410 frames, score 2, max score 12
# Completed 552 games, 1226 rewards, 313072 frames, score 1, max score 12
# Completed 553 games, 1229 rewards, 314386 frames, score 2, max score 12
# Completed 554 games, 1230 rewards, 314567 frames, score 0, max score 12
# Completed 555 games, 1233 rewards, 315232 frames, score 2, max score 12
# Completed 556 games, 1239 rewards, 317951 frames, score 5, max score 12
# Completed 557 games, 1242 rewards, 318866 frames, score 2, max score 12
# Completed 558 games, 1245 rewards, 319667 frames, score 2, max score 12
# Completed 559 games, 1246 rewards, 319848 frames, score 0, max score 12
# Completed 560 games, 1248 rewards, 320246 frames, score 1, max score 12
# Completed 561 games, 1251 rewards, 320994 frames, score 2, max score 12
# Completed 562 games, 1252 rewards, 321248 frames, score 0, max score 12
# Completed 563 games, 1257 rewards, 322220 frames, score 4, max score 12
# Completed 564 games, 1263 rewards, 323348 frames, score 5, max score 12
# Completed 565 games, 1264 rewards, 323602 frames, score 0, max score 12
# Completed 566 games, 1265 rewards, 323856 frames, score 0, max score 12
# Completed 567 games, 1267 rewards, 324344 frames, score 1, max score 12
# Completed 568 games, 1268 rewards, 324598 frames, score 0, max score 12
# Completed 569 games, 1269 rewards, 324779 frames, score 0, max score 12
# Completed 570 games, 1273 rewards, 325827 frames, score 3, max score 12
# Completed 571 games, 1274 rewards, 326081 frames, score 0, max score 12
# Completed 572 games, 1275 rewards, 326289 frames, score 0, max score 12
# Completed 573 games, 1281 rewards, 327482 frames, score 5, max score 12
# Completed 574 games, 1282 rewards, 327663 frames, score 0, max score 12
# Completed 575 games, 1286 rewards, 328986 frames, score 3, max score 12
# Completed 576 games, 1287 rewards, 329194 frames, score 0, max score 12
# Completed 577 games, 1290 rewards, 329792 frames, score 2, max score 12
# Completed 578 games, 1291 rewards, 330000 frames, score 0, max score 12
# Completed 579 games, 1292 rewards, 330181 frames, score 0, max score 12
# Completed 580 games, 1294 rewards, 330522 frames, score 1, max score 12
# Completed 581 games, 1298 rewards, 331348 frames, score 3, max score 12
# Completed 582 games, 1301 rewards, 331880 frames, score 2, max score 12
# Completed 583 games, 1302 rewards, 332088 frames, score 0, max score 12
# Completed 584 games, 1305 rewards, 332925 frames, score 2, max score 12
# Completed 585 games, 1308 rewards, 333472 frames, score 2, max score 12
# Completed 586 games, 1310 rewards, 333969 frames, score 1, max score 12
# Completed 587 games, 1311 rewards, 334223 frames, score 0, max score 12
# Completed 588 games, 1314 rewards, 334770 frames, score 2, max score 12
# Completed 589 games, 1318 rewards, 335627 frames, score 3, max score 12
# Completed 590 games, 1320 rewards, 336025 frames, score 1, max score 12
# Completed 591 games, 1321 rewards, 336279 frames, score 0, max score 12
# Completed 592 games, 1323 rewards, 336830 frames, score 1, max score 12
# Completed 593 games, 1327 rewards, 339226 frames, score 3, max score 12
# Completed 594 games, 1330 rewards, 339867 frames, score 2, max score 12
# Completed 595 games, 1332 rewards, 340272 frames, score 1, max score 12
# Completed 596 games, 1342 rewards, 346135 frames, score 9, max score 12
# Completed 597 games, 1348 rewards, 347014 frames, score 5, max score 12
# Completed 598 games, 1350 rewards, 347676 frames, score 1, max score 12
# Completed 599 games, 1352 rewards, 348173 frames, score 1, max score 12
# Completed 600 games, 1355 rewards, 349025 frames, score 2, max score 12
# Completed 601 games, 1359 rewards, 349817 frames, score 3, max score 12
# Completed 602 games, 1361 rewards, 350200 frames, score 1, max score 12
# Completed 603 games, 1362 rewards, 350381 frames, score 0, max score 12
# Completed 604 games, 1366 rewards, 351014 frames, score 3, max score 12
# Completed 605 games, 1368 rewards, 351428 frames, score 1, max score 12
# Completed 606 games, 1371 rewards, 352185 frames, score 2, max score 12
# Completed 607 games, 1372 rewards, 352393 frames, score 0, max score 12
# Completed 608 games, 1373 rewards, 352601 frames, score 0, max score 12
# Completed 609 games, 1375 rewards, 353191 frames, score 1, max score 12
# Completed 610 games, 1377 rewards, 353793 frames, score 1, max score 12
# Completed 611 games, 1380 rewards, 354358 frames, score 2, max score 12
# Completed 612 games, 1385 rewards, 356454 frames, score 4, max score 12
# Completed 613 games, 1389 rewards, 357086 frames, score 3, max score 12
# Completed 614 games, 1390 rewards, 357294 frames, score 0, max score 12
# Completed 615 games, 1392 rewards, 357845 frames, score 1, max score 12
# Completed 616 games, 1395 rewards, 358656 frames, score 2, max score 12
# Completed 617 games, 1398 rewards, 359504 frames, score 2, max score 12
# Completed 618 games, 1403 rewards, 363397 frames, score 4, max score 12
# Completed 619 games, 1408 rewards, 364760 frames, score 4, max score 12
# Completed 620 games, 1412 rewards, 365721 frames, score 3, max score 12
# Completed 621 games, 1415 rewards, 366793 frames, score 2, max score 12
# Completed 622 games, 1418 rewards, 367747 frames, score 2, max score 12
# Completed 623 games, 1422 rewards, 368678 frames, score 3, max score 12
# Completed 624 games, 1426 rewards, 369422 frames, score 3, max score 12
# Completed 625 games, 1429 rewards, 369942 frames, score 2, max score 12
# Completed 626 games, 1430 rewards, 370150 frames, score 0, max score 12
# Completed 627 games, 1431 rewards, 370358 frames, score 0, max score 12
# Completed 628 games, 1434 rewards, 370946 frames, score 2, max score 12
# Completed 629 games, 1438 rewards, 371737 frames, score 3, max score 12
# Completed 630 games, 1439 rewards, 371918 frames, score 0, max score 12
# Completed 631 games, 1441 rewards, 372323 frames, score 1, max score 12
# Completed 632 games, 1444 rewards, 372837 frames, score 2, max score 12
# Completed 633 games, 1445 rewards, 373091 frames, score 0, max score 12
# Completed 634 games, 1447 rewards, 373528 frames, score 1, max score 12
# Completed 635 games, 1451 rewards, 374236 frames, score 3, max score 12
# Completed 636 games, 1454 rewards, 374955 frames, score 2, max score 12
# Completed 637 games, 1456 rewards, 375506 frames, score 1, max score 12
# Completed 638 games, 1459 rewards, 376179 frames, score 2, max score 12
# Completed 639 games, 1460 rewards, 376387 frames, score 0, max score 12
# Completed 640 games, 1465 rewards, 377485 frames, score 4, max score 12
# Completed 641 games, 1468 rewards, 378420 frames, score 2, max score 12
# Completed 642 games, 1471 rewards, 378974 frames, score 2, max score 12
# Completed 643 games, 1479 rewards, 380283 frames, score 7, max score 12
# Completed 644 games, 1482 rewards, 380983 frames, score 2, max score 12
# Completed 645 games, 1486 rewards, 381644 frames, score 3, max score 12
# Completed 646 games, 1488 rewards, 382011 frames, score 1, max score 12
# Completed 647 games, 1498 rewards, 384505 frames, score 9, max score 12
# Completed 648 games, 1500 rewards, 384881 frames, score 1, max score 12
# Completed 649 games, 1501 rewards, 385089 frames, score 0, max score 12
# Completed 650 games, 1504 rewards, 385830 frames, score 2, max score 12
# Completed 651 games, 1511 rewards, 388015 frames, score 6, max score 12
# Completed 652 games, 1515 rewards, 389071 frames, score 3, max score 12
# Completed 653 games, 1516 rewards, 389325 frames, score 0, max score 12
# Completed 654 games, 1518 rewards, 389762 frames, score 1, max score 12
# Completed 655 games, 1521 rewards, 390320 frames, score 2, max score 12
# Completed 656 games, 1524 rewards, 390836 frames, score 2, max score 12
# Completed 657 games, 1528 rewards, 391726 frames, score 3, max score 12
# Completed 658 games, 1531 rewards, 392492 frames, score 2, max score 12
# Completed 659 games, 1532 rewards, 392673 frames, score 0, max score 12
# Completed 660 games, 1533 rewards, 392881 frames, score 0, max score 12
# Completed 661 games, 1534 rewards, 393135 frames, score 0, max score 12
# Completed 662 games, 1537 rewards, 393693 frames, score 2, max score 12
# Completed 663 games, 1540 rewards, 394173 frames, score 2, max score 12
# Completed 664 games, 1553 rewards, 404582 frames, score 12, max score 12
# Completed 665 games, 1561 rewards, 405903 frames, score 7, max score 12
# Completed 666 games, 1566 rewards, 407218 frames, score 4, max score 12
# Completed 667 games, 1569 rewards, 408183 frames, score 2, max score 12
# Completed 668 games, 1570 rewards, 408437 frames, score 0, max score 12
# Completed 669 games, 1572 rewards, 408804 frames, score 1, max score 12
# Completed 670 games, 1575 rewards, 409842 frames, score 2, max score 12
# Completed 671 games, 1576 rewards, 410050 frames, score 0, max score 12
# Completed 672 games, 1577 rewards, 410304 frames, score 0, max score 12
# Completed 673 games, 1580 rewards, 410995 frames, score 2, max score 12
# Completed 674 games, 1584 rewards, 412009 frames, score 3, max score 12
# Completed 675 games, 1589 rewards, 412812 frames, score 4, max score 12
# Completed 676 games, 1595 rewards, 413745 frames, score 5, max score 12
# Completed 677 games, 1596 rewards, 413953 frames, score 0, max score 12
# Completed 678 games, 1604 rewards, 415663 frames, score 7, max score 12
# Completed 679 games, 1609 rewards, 417228 frames, score 4, max score 12
# Completed 680 games, 1610 rewards, 417436 frames, score 0, max score 12
# Completed 681 games, 1615 rewards, 419104 frames, score 4, max score 12
# Completed 682 games, 1621 rewards, 420270 frames, score 5, max score 12
# Completed 683 games, 1622 rewards, 420524 frames, score 0, max score 12
# Completed 684 games, 1629 rewards, 421464 frames, score 6, max score 12
# ...
# Completed 4799 games, 48666 rewards, 11359999 frames, score 24, max score 177
# Completed 4800 games, 48775 rewards, 11378671 frames, score 108, max score 177
# Completed 4801 games, 48782 rewards, 11380133 frames, score 6, max score 177
# Completed 4802 games, 48801 rewards, 11383254 frames, score 18, max score 177
# Completed 4803 games, 48866 rewards, 11393206 frames, score 64, max score 177
# Completed 4804 games, 48952 rewards, 11407883 frames, score 85, max score 177
# Completed 4805 games, 48988 rewards, 11413888 frames, score 35, max score 177
# Completed 4806 games, 49005 rewards, 11417027 frames, score 16, max score 177
# Completed 4807 games, 49050 rewards, 11431899 frames, score 44, max score 177
# Completed 4808 games, 49073 rewards, 11435535 frames, score 22, max score 177
# Completed 4809 games, 49128 rewards, 11468992 frames, score 54, max score 177
# Completed 4810 games, 49137 rewards, 11470593 frames, score 8, max score 177
# Completed 4811 games, 49199 rewards, 11480186 frames, score 61, max score 177
# Completed 4812 games, 49267 rewards, 11511674 frames, score 67, max score 177
# Completed 4813 games, 49278 rewards, 11514078 frames, score 10, max score 177
# Completed 4814 games, 49299 rewards, 11517325 frames, score 20, max score 177
# Completed 4815 games, 49332 rewards, 11527237 frames, score 32, max score 177
# Completed 4816 games, 49441 rewards, 11550100 frames, score 108, max score 177
# Completed 4817 games, 49656 rewards, 11586949 frames, score 214, max score 214
# Completed 4818 games, 49692 rewards, 11596722 frames, score 35, max score 214
# Completed 4819 games, 49890 rewards, 11625996 frames, score 197, max score 214
# Completed 4820 games, 49941 rewards, 11634458 frames, score 50, max score 214
# Completed 4821 games, 49997 rewards, 11648097 frames, score 55, max score 214
# Completed 4822 games, 50066 rewards, 11665045 frames, score 68, max score 214
# Completed 4823 games, 50077 rewards, 11666829 frames, score 10, max score 214
# Completed 4824 games, 50308 rewards, 11712040 frames, score 230, max score 230
# Completed 4825 games, 50597 rewards, 11759004 frames, score 288, max score 288
# Completed 4826 games, 50676 rewards, 11772104 frames, score 78, max score 288
# Completed 4827 games, 50976 rewards, 11816912 frames, score 299, max score 299
# Completed 4828 games, 51133 rewards, 11843887 frames, score 156, max score 299
# Completed 4829 games, 51489 rewards, 11897711 frames, score 355, max score 355
# Completed 4830 games, 51726 rewards, 11936093 frames, score 236, max score 355
# Completed 4831 games, 51845 rewards, 11961853 frames, score 118, max score 355
# Completed 4832 games, 52657 rewards, 12124080 frames, score 811, max score 811
# Completed 4833 games, 52686 rewards, 12130436 frames, score 28, max score 811
# Completed 4834 games, 52717 rewards, 12137209 frames, score 30, max score 811
# Completed 4835 games, 52886 rewards, 12166177 frames, score 168, max score 811
# Completed 4836 games, 52939 rewards, 12175176 frames, score 52, max score 811
# Completed 4837 games, 53220 rewards, 12226140 frames, score 280, max score 811
# Completed 4838 games, 53406 rewards, 12271587 frames, score 185, max score 811
# Completed 4839 games, 53536 rewards, 12296452 frames, score 129, max score 811
# Completed 4840 games, 53659 rewards, 12326320 frames, score 122, max score 811
# Completed 4841 games, 54137 rewards, 12407689 frames, score 477, max score 811
# Completed 4842 games, 54338 rewards, 12441868 frames, score 200, max score 811
# Completed 4843 games, 54804 rewards, 12519621 frames, score 465, max score 811
# Completed 4844 games, 55058 rewards, 12561985 frames, score 253, max score 811
# Completed 4845 games, 55821 rewards, 12695826 frames, score 762, max score 811
# Completed 4846 games, 55969 rewards, 12739824 frames, score 147, max score 811
# Completed 4847 games, 56155 rewards, 12792284 frames, score 185, max score 811
# Completed 4848 games, 57267 rewards, 12996072 frames, score 1111, max score 1111
# Completed 4849 games, 57409 rewards, 13024331 frames, score 141, max score 1111
# Completed 4850 games, 57563 rewards, 13047602 frames, score 153, max score 1111
# Completed 4851 games, 57591 rewards, 13051782 frames, score 27, max score 1111
# Completed 4852 games, 57795 rewards, 13093285 frames, score 203, max score 1111
# Completed 4853 games, 58121 rewards, 13146994 frames, score 325, max score 1111
# Completed 4854 games, 58153 rewards, 13151816 frames, score 31, max score 1111
# Completed 4855 games, 58362 rewards, 13208938 frames, score 208, max score 1111
# Completed 4856 games, 58509 rewards, 13248894 frames, score 146, max score 1111
# Completed 4857 games, 58561 rewards, 13259027 frames, score 51, max score 1111
# Completed 4858 games, 58681 rewards, 13281459 frames, score 119, max score 1111
# Completed 4859 games, 59039 rewards, 13353085 frames, score 357, max score 1111
# Completed 4860 games, 59111 rewards, 13370138 frames, score 71, max score 1111
# Completed 4861 games, 59233 rewards, 13396017 frames, score 121, max score 1111
# Completed 4862 games, 59499 rewards, 13445411 frames, score 265, max score 1111
# Completed 4863 games, 59713 rewards, 13483492 frames, score 213, max score 1111
# Completed 4864 games, 59773 rewards, 13493668 frames, score 59, max score 1111
# Completed 4865 games, 59840 rewards, 13505162 frames, score 66, max score 1111
# Completed 4866 games, 60069 rewards, 13543242 frames, score 228, max score 1111
# Completed 4867 games, 60498 rewards, 13621730 frames, score 428, max score 1111
# Completed 4868 games, 60633 rewards, 13645377 frames, score 134, max score 1111
# Completed 4869 games, 60644 rewards, 13647426 frames, score 10, max score 1111
# Completed 4870 games, 60659 rewards, 13649685 frames, score 14, max score 1111
# Completed 4871 games, 60706 rewards, 13657683 frames, score 46, max score 1111
# Completed 4872 games, 60713 rewards, 13659200 frames, score 6, max score 1111
# Completed 4873 games, 60765 rewards, 13667381 frames, score 51, max score 1111
# Completed 4874 games, 61084 rewards, 13727246 frames, score 318, max score 1111
# Completed 4875 games, 61107 rewards, 13731203 frames, score 22, max score 1111
# Completed 4876 games, 61255 rewards, 13756790 frames, score 147, max score 1111
# Completed 4877 games, 61817 rewards, 13864749 frames, score 561, max score 1111
# Completed 4878 games, 61926 rewards, 13892436 frames, score 108, max score 1111
# Completed 4879 games, 62105 rewards, 13919488 frames, score 178, max score 1111
# Completed 4880 games, 62440 rewards, 13969833 frames, score 334, max score 1111
# Completed 4881 games, 63039 rewards, 14076720 frames, score 598, max score 1111
# Completed 4882 games, 63170 rewards, 14096327 frames, score 130, max score 1111
# Completed 4883 games, 63350 rewards, 14132462 frames, score 179, max score 1111
# Completed 4884 games, 63554 rewards, 14164800 frames, score 203, max score 1111
# Completed 4885 games, 63703 rewards, 14201279 frames, score 148, max score 1111
# Completed 4886 games, 64685 rewards, 14371678 frames, score 981, max score 1111
# Completed 4887 games, 64831 rewards, 14395317 frames, score 145, max score 1111
# Completed 4888 games, 64905 rewards, 14412275 frames, score 73, max score 1111
# Completed 4889 games, 64919 rewards, 14414689 frames, score 13, max score 1111
# Completed 4890 games, 64998 rewards, 14431654 frames, score 78, max score 1111
# Completed 4891 games, 65106 rewards, 14454093 frames, score 107, max score 1111
# Completed 4892 games, 65180 rewards, 14468055 frames, score 73, max score 1111
# Completed 4893 games, 65216 rewards, 14474778 frames, score 35, max score 1111
# Completed 4894 games, 65219 rewards, 14475888 frames, score 2, max score 1111
# Completed 4895 games, 65268 rewards, 14484989 frames, score 48, max score 1111
# Completed 4896 games, 65273 rewards, 14485989 frames, score 4, max score 1111
# Completed 4897 games, 65277 rewards, 14486940 frames, score 3, max score 1111
# Completed 4898 games, 65334 rewards, 14501590 frames, score 56, max score 1111
# Completed 4899 games, 65339 rewards, 14502511 frames, score 4, max score 1111
# Completed 4900 games, 65350 rewards, 14504182 frames, score 10, max score 1111
# Completed 4901 games, 65572 rewards, 14550941 frames, score 221, max score 1111
# Completed 4902 games, 65586 rewards, 14553136 frames, score 13, max score 1111
# Completed 4903 games, 65593 rewards, 14554208 frames, score 6, max score 1111
# Completed 4904 games, 65623 rewards, 14562402 frames, score 29, max score 1111
# Completed 4905 games, 65657 rewards, 14567462 frames, score 33, max score 1111
# Completed 4906 games, 65684 rewards, 14571830 frames, score 26, max score 1111
# Completed 4907 games, 65688 rewards, 14572665 frames, score 3, max score 1111
# Completed 4908 games, 65717 rewards, 14577118 frames, score 28, max score 1111
# Completed 4909 games, 65785 rewards, 14588994 frames, score 67, max score 1111
# Completed 4910 games, 65842 rewards, 14599220 frames, score 56, max score 1111
# Completed 4911 games, 65879 rewards, 14605268 frames, score 36, max score 1111
# Completed 4912 games, 65880 rewards, 14605449 frames, score 0, max score 1111
# Completed 4913 games, 65900 rewards, 14611769 frames, score 19, max score 1111
# Completed 4914 games, 65907 rewards, 14613038 frames, score 6, max score 1111
# Completed 4915 games, 65954 rewards, 14621129 frames, score 46, max score 1111
# Completed 4916 games, 65979 rewards, 14625381 frames, score 24, max score 1111
# Completed 4917 games, 66086 rewards, 14661345 frames, score 106, max score 1111
# Completed 4918 games, 66113 rewards, 14669489 frames, score 26, max score 1111
# Completed 4919 games, 66148 rewards, 14674810 frames, score 34, max score 1111
# Completed 4920 games, 66203 rewards, 14688127 frames, score 54, max score 1111
# Completed 4921 games, 66256 rewards, 14718812 frames, score 52, max score 1111
# Completed 4922 games, 66257 rewards, 14719066 frames, score 0, max score 1111
# Completed 4923 games, 66281 rewards, 14725546 frames, score 23, max score 1111
# Completed 4924 games, 66284 rewards, 14726227 frames, score 2, max score 1111
# Completed 4925 games, 66294 rewards, 14727862 frames, score 9, max score 1111
# Completed 4926 games, 66309 rewards, 14730353 frames, score 14, max score 1111
# Completed 4927 games, 66354 rewards, 14738878 frames, score 44, max score 1111
# Completed 4928 games, 66364 rewards, 14740536 frames, score 9, max score 1111
# Completed 4929 games, 66379 rewards, 14742875 frames, score 14, max score 1111
# Completed 4930 games, 66385 rewards, 14744007 frames, score 5, max score 1111
# Completed 4931 games, 66456 rewards, 14758310 frames, score 70, max score 1111
# Completed 4932 games, 66469 rewards, 14760428 frames, score 12, max score 1111
# Completed 4933 games, 66477 rewards, 14761976 frames, score 7, max score 1111
# Completed 4934 games, 66536 rewards, 14779100 frames, score 58, max score 1111
# Completed 4935 games, 66544 rewards, 14781047 frames, score 7, max score 1111
# Completed 4936 games, 66552 rewards, 14782457 frames, score 7, max score 1111
# Completed 4937 games, 66561 rewards, 14783903 frames, score 8, max score 1111
# Completed 4938 games, 66580 rewards, 14787087 frames, score 18, max score 1111
# Completed 4939 games, 66590 rewards, 14788639 frames, score 9, max score 1111
# Completed 4940 games, 66624 rewards, 14801709 frames, score 33, max score 1111
# Completed 4941 games, 66694 rewards, 14826113 frames, score 69, max score 1111
# Completed 4942 games, 66696 rewards, 14826664 frames, score 1, max score 1111
# Completed 4943 games, 66717 rewards, 14830248 frames, score 20, max score 1111
# Completed 4944 games, 66732 rewards, 14834858 frames, score 14, max score 1111
# Completed 4945 games, 66762 rewards, 14840426 frames, score 29, max score 1111
# Completed 4946 games, 66767 rewards, 14842704 frames, score 4, max score 1111
# Completed 4947 games, 66772 rewards, 14843671 frames, score 4, max score 1111
# Completed 4948 games, 66794 rewards, 14847233 frames, score 21, max score 1111
# Completed 4949 games, 66811 rewards, 14850998 frames, score 16, max score 1111
# Completed 4950 games, 66815 rewards, 14852360 frames, score 3, max score 1111
# Completed 4951 games, 66845 rewards, 14861952 frames, score 29, max score 1111
# Completed 4952 games, 66866 rewards, 14865412 frames, score 20, max score 1111
# Completed 4953 games, 66868 rewards, 14865900 frames, score 1, max score 1111
# Completed 4954 games, 66872 rewards, 14866792 frames, score 3, max score 1111
# Completed 4955 games, 66887 rewards, 14869120 frames, score 14, max score 1111
# Completed 4956 games, 66890 rewards, 14870332 frames, score 2, max score 1111
# Completed 4957 games, 66930 rewards, 14876683 frames, score 39, max score 1111
# Completed 4958 games, 66947 rewards, 14881246 frames, score 16, max score 1111
# Completed 4959 games, 66954 rewards, 14882649 frames, score 6, max score 1111
# Completed 4960 games, 66956 rewards, 14883239 frames, score 1, max score 1111
# Completed 4961 games, 66988 rewards, 14891760 frames, score 31, max score 1111
# Completed 4962 games, 67008 rewards, 14894894 frames, score 19, max score 1111
# Completed 4963 games, 67026 rewards, 14898070 frames, score 17, max score 1111
# Completed 4964 games, 67031 rewards, 14898830 frames, score 4, max score 1111
# Completed 4965 games, 67043 rewards, 14900986 frames, score 11, max score 1111
# Completed 4966 games, 67048 rewards, 14901941 frames, score 4, max score 1111
# Completed 4967 games, 67061 rewards, 14904036 frames, score 12, max score 1111
# Completed 4968 games, 67062 rewards, 14904244 frames, score 0, max score 1111
# Completed 4969 games, 67098 rewards, 14910101 frames, score 35, max score 1111
# Completed 4970 games, 67114 rewards, 14912683 frames, score 15, max score 1111
# Completed 4971 games, 67123 rewards, 14914126 frames, score 8, max score 1111
# Completed 4972 games, 67150 rewards, 14920244 frames, score 26, max score 1111
# Completed 4973 games, 67166 rewards, 14923892 frames, score 15, max score 1111
# Completed 4974 games, 67176 rewards, 14926174 frames, score 9, max score 1111
# Completed 4975 games, 67182 rewards, 14927148 frames, score 5, max score 1111
# Completed 4976 games, 67184 rewards, 14927515 frames, score 1, max score 1111
# Completed 4977 games, 67188 rewards, 14928159 frames, score 3, max score 1111
# Completed 4978 games, 67201 rewards, 14931921 frames, score 12, max score 1111
# Completed 4979 games, 67216 rewards, 14934465 frames, score 14, max score 1111
# Completed 4980 games, 67220 rewards, 14935573 frames, score 3, max score 1111
# Completed 4981 games, 67230 rewards, 14940406 frames, score 9, max score 1111
# Completed 4982 games, 67234 rewards, 14941803 frames, score 3, max score 1111
# Completed 4983 games, 67238 rewards, 14942556 frames, score 3, max score 1111
# Completed 4984 games, 67239 rewards, 14942737 frames, score 0, max score 1111
# Completed 4985 games, 67243 rewards, 14943426 frames, score 3, max score 1111
# Completed 4986 games, 67269 rewards, 14948694 frames, score 25, max score 1111
# Completed 4987 games, 67286 rewards, 14951496 frames, score 16, max score 1111
# Completed 4988 games, 67302 rewards, 14954646 frames, score 15, max score 1111
# Completed 4989 games, 67308 rewards, 14955619 frames, score 5, max score 1111
# Completed 4990 games, 67309 rewards, 14955800 frames, score 0, max score 1111
# Completed 4991 games, 67335 rewards, 14962023 frames, score 25, max score 1111
# Completed 4992 games, 67372 rewards, 14973135 frames, score 36, max score 1111
# Completed 4993 games, 67383 rewards, 14978384 frames, score 10, max score 1111
# Completed 4994 games, 67389 rewards, 14979696 frames, score 5, max score 1111
# Completed 4995 games, 67437 rewards, 14987993 frames, score 47, max score 1111
# Completed 4996 games, 67451 rewards, 14990676 frames, score 13, max score 1111
# Completed 4997 games, 67491 rewards, 14999736 frames, score 39, max score 1111
# Completed 4998 games, 67508 rewards, 15002724 frames, score 16, max score 1111
# Completed 4999 games, 67554 rewards, 15010012 frames, score 45, max score 1111
# The number of games played was 5000
# The number of video frames was 5000
# The size of each returned Q-matrix was (0,)

# %% [markdown]
# Now let's plot the score, to see if it improved over time.  We will also plot the local average, averaged over 10 consecutive games, to see if that has improved.  Notice that we can use `np.convolve` to compute the local average.
#
# These numbers are really noisy, with a really large maximum.  We will plot `np.log10(1+x)`, rather than x, so that we can better see the average numbers, and ignore the very large noisy spikes.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,9),layout='tight')
ax = [ fig.add_subplot(3,1,x) for x in range(1,4) ]
ax[0].plot(np.arange(0,len(scores)),np.log10(1+np.array(scores)))
ax[0].plot([0,5000],np.log10([7,7]),'k--')
ax[0].set_title('Game scores')
ax[1].plot(np.arange(4991),np.log10(1+np.convolve(np.ones(10)/10,scores,mode='valid')))
ax[1].plot([0,4991],np.log10([7,7]),'k--')
ax[1].set_title('Game scores, average 10 consecutive games')
ax[2].plot(np.arange(0,len(q_achieved)),q_achieved)
ax[2].set_title('Q values of state achieved at each time')
ax[2].set_ylabel('Game number')
# Out:
# Text(0, 0.5, 'Game number')

# %% [markdown]
# Hooray, it has learned!  If you are getting a ten-game average score of better than 6, then you are ready to submit your model for grading.   In order to do that, you need to save the model:

# %%
q_learner.save('trained_model.npz')

# %% [markdown]
# <a id='section9'></a>

# %% [markdown]
# ## Extra Credit

# %% [markdown]
# For extra credit, download the file <a href="mp11_extra.zip">mp11_extra.zip</a>.  The only important file in this package is:
# * `tests/test_extra.py`: this contains extra tests that will evaluate your pre-trained `deep_q` learner, which should be in a file called `trained_model.pkl`.  For full credit, your model should achieve an average score of greater than 20, averaged over 10 consecutive games.
#
# With a quantized lookup table, it's probably not possible to achieve an average score of 20.  With a deep-Q learner, however, it is eminently possible.  In order to do the extra credit, therefore, you should just fill in the part of `submitted.py` that implements the `deep_q` learner, using pytorch to define a model structure, train it, save it, load it, and act on it.  This learner only needs to have five methods: `__init__`, `act`, `learn`, `save`, and `load`:

# %%
importlib.reload(submitted)
help(submitted.deep_q.__init__)
# Out:
# Help on function __init__ in module submitted:
#
# __init__(self, alpha, epsilon, gamma, nfirst)
#     Create a new deep_q learner.
#     Your q_learner object should store the provided values of alpha,
#     epsilon, gamma, and nfirst.
#     It should also create a deep learning model that will accept
#     (state,action) as input, and estimate Q as the output.
#
#     @params:
#     alpha (scalar) - learning rate of the Q-learner
#     epsilon (scalar) - probability of taking a random action
#     gamma (scalar) - discount factor
#     nfirst (scalar) - exploring each state/action pair nfirst times before exploiting
#
#     @return:
#     None

# %%
help(submitted.deep_q.act)
# Out:
# Help on function act in module submitted:
#
# act(self, state)
#     Decide what action to take in the current state.
#     You are free to determine your own exploration/exploitation policy --
#     you don't need to use the epsilon and nfirst provided to you.
#
#     @params:
#     state: a list of 5 floats: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#
#     @return:
#     -1 if the paddle should move upward
#     0 if the paddle should be stationary
#     1 if the paddle should move downward

# %%
help(submitted.deep_q.learn)
# Out:
# Help on function learn in module submitted:
#
# learn(self, state, action, reward, newstate)
#     Perform one iteration of training on a deep-Q model.
#
#     @params:
#     state: a list of 5 floats: ball_x, ball_y, ball_vx, ball_vy, paddle_y
#     action: an integer, one of -1, 0, or +1
#     reward: a reward; positive for hitting the ball, negative for losing a game
#     newstate: a list of 5 floats, in the same format as state
#
#     @return:
#     None

# %%
help(submitted.deep_q.save)
# Out:
# Help on function save in module submitted:
#
# save(self, filename)
#     Save your trained deep-Q model to a file.
#     This can save in any format you like, as long as your "load"
#     function uses the same file format.
#
#     @params:
#     filename (str) - filename to which it should be saved
#     @return:
#     None

# %%
help(submitted.deep_q.load)
# Out:
# Help on function load in module submitted:
#
# load(self, filename)
#     Load your deep-Q model from a file.
#     This should load from whatever file format your save function
#     used.
#
#     @params:
#     filename (str) - filename from which it should be loaded
#     @return:
#     None

# %% [markdown]
# <a id='grade'></a>

# %% [markdown]
# ## Grade your homework

# %% [markdown]
# If you've reached this point, and all of the above sections work, then you're ready to try grading your homework!  Before you submit it to Gradescope, try grading it on your own machine.  This will run some visible test cases (which you can read in `tests/test_visible.py`), and compare the results to the solutions (which you can read in `solution.json`).
#
# The exclamation point (!) tells python to run the following as a shell command.  Obviously you don't need to run the code this way -- this usage is here just to remind you that you can also, if you wish, run this command in a terminal window.

# %%
# !python grade.py
# Out:
# .....Completed 0 games, 30 rewards, 8125 frames, score 29, max score 29
# Completed 1 games, 48 rewards, 10886 frames, score 17, max score 29
# Completed 2 games, 64 rewards, 16802 frames, score 15, max score 29
# Completed 3 games, 71 rewards, 21221 frames, score 6, max score 29
# Completed 4 games, 86 rewards, 25431 frames, score 14, max score 29
# Completed 5 games, 89 rewards, 26294 frames, score 2, max score 29
# Completed 6 games, 99 rewards, 29810 frames, score 9, max score 29
# Completed 7 games, 119 rewards, 33539 frames, score 19, max score 29
# Completed 8 games, 131 rewards, 37423 frames, score 11, max score 29
# Completed 9 games, 133 rewards, 38157 frames, score 1, max score 29
# .
# ----------------------------------------------------------------------
# Ran 6 tests in 1.187s
#
# OK

# %% [markdown]
# Now you should try uploading your code to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
#
# **Warning:** For this MP you need to update two files, not just one.
# * `trained_model.npz` should contain your trained model
# * `submitted.py` should contain your code that loads and runs your trained model.
#
# **Warning:** The autograder calculates the average score over ten random games.  If you are getting an average score above 10 almost all the time on your own computer, and if the autograder says you had a score below 10, try resubmitting to see if the next round of random games is better.
#
# **Extra Credit:** Your extra credit should also be uploaded as two files,
# * `trained_model.pkl` should contain your trained model
# * `submitted.py` should contain your code that loads and runs your trained model.
